# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import nltk
import string
import re
from os import path
from PIL import Image

from spellchecker import SpellChecker
from nltk import FreqDist
from collections import Counter
from collections import defaultdict
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob

from nltk.tokenize import TweetTokenizer

tknzr = TweetTokenizer(strip_handles=True)

# %%
stop_words = stopwords.words('english')

# %%
df_train = pd.read_csv("dataset/train.csv")
df_test= pd.read_csv("dataset/test.csv")
pd.set_option('display.max_colwidth', -1) #elimino limite de truncado para visualizacion
# Out:
# /home/pablo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## Construccion de Features

# %%
# contador de palabras
df_train['word_count'] = df_train['text'].apply(lambda x: len(str(x).split()))
df_test['word_count'] = df_test['text'].apply(lambda x: len(str(x).split()))

# palabras unicas
df_train['unique_word_count'] = df_train['text'].apply(lambda x: len(set(str(x).split())))
df_test['unique_word_count'] = df_test['text'].apply(lambda x: len(set(str(x).split())))

# contador de stopwords
df_train['stop_word_count'] = df_train['text'].apply(lambda x: len([w for w in str(x).lower().split() if w in STOPWORDS]))
df_test['stop_word_count'] = df_test['text'].apply(lambda x: len([w for w in str(x).lower().split() if w in STOPWORDS]))

# contador de url
df_train['url_count'] = df_train['text'].apply(lambda x: len([w for w in str(x).lower().split() if 'http' in w or 'https' in w]))
df_test['url_count'] = df_test['text'].apply(lambda x: len([w for w in str(x).lower().split() if 'http' in w or 'https' in w]))

# extractor de emails
df_train['emails'] = df_train['text'].apply(lambda x: re.findall(r'([a-zA-Z0-9+._-]+@[a-zA-Z0-9+._-]+\.[a-zA-Z0-9+._-]+)', x))
df_test['emails'] = df_test['text'].apply(lambda x: re.findall(r'([a-zA-Z0-9+._-]+@[a-zA-Z0-9+._-]+\.[a-zA-Z0-9+._-]+)', x))

# contador de emails
df_train['emails_count'] = df_train['emails'].apply(lambda x: len(x))
df_test['emails_count'] = df_test['emails'].apply(lambda x: len(x))

# promedio del largo de palabras
df_train['mean_word_length'] = df_train['text'].apply(lambda x: np.mean([len(w) for w in str(x).split()]))
df_test['mean_word_length'] = df_test['text'].apply(lambda x: np.mean([len(w) for w in str(x).split()]))

# contador de caracteres
df_train['char_count'] = df_train['text'].apply(lambda x: len(str(x)))
df_test['char_count'] = df_test['text'].apply(lambda x: len(str(x)))

# contador de numeros
df_train['number_count'] = df_train['text'].apply(lambda x: len([w for w in x.split() if w.isdigit()]))
df_test['number_count'] = df_test['text'].apply(lambda x: len([w for w in x.split() if w.isdigit()]))

# contador de mayuscuslas en palabras 
df_train['upper_count'] = df_train['text'].apply(lambda x: len([w for w in x.split() if w.isupper() and len(x)>3]))
df_test['upper_count'] = df_test['text'].apply(lambda x: len([w for w in x.split() if w.isupper() and len(x)>3]))

# contador de puntuaciones
df_train['punctuation_count'] = df_train['text'].apply(lambda x: len([c for c in str(x) if c in string.punctuation]))
df_test['punctuation_count'] = df_test['text'].apply(lambda x: len([c for c in str(x) if c in string.punctuation]))

# contador de hashtags
df_train['hashtag_count'] = df_train['text'].apply(lambda x: len([c for c in str(x) if c == '#']))
df_test['hashtag_count'] = df_test['text'].apply(lambda x: len([c for c in str(x) if c == '#']))

# contador de menciones
df_train['mention_count'] = df_train['text'].apply(lambda x: len([c for c in str(x) if c == '@']))
df_test['mention_count'] = df_test['text'].apply(lambda x: len([c for c in str(x) if c == '@']))

# %% [markdown]
# ## Limpieza del Texto

# %%
from pycontractions import Contractions
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
import gensim.downloader as api
wv = api.load('word2vec-google-news-300')
# Out:
# 2020-08-03 23:53:44,562 : INFO : Creating /home/pablo/gensim-data
# [==================================================] 100.0% 1662.8/1662.8MB downloaded
# 2020-08-04 00:08:29,615 : INFO : word2vec-google-news-300 downloaded
# 2020-08-04 00:08:29,701 : INFO : loading projection weights from /home/pablo/gensim-data/word2vec-google-news-300/word2vec-google-news-300.gz

# %%
# con el fin de agilizar el tiempo para la construccion de algunos filtros se han recolectado de diferentes fuentes

contracciones = {
  "ain't": "am not",
  "aren't": "are not",
  "can't": "cannot",
  "can't've": "cannot have",
  "'cause": "because",
  "could've": "could have",
  "couldn't": "could not",
  "couldn't've": "could not have",
  "didn't": "did not",
  "doesn't": "does not",
  "don't": "do not",
  "hadn't": "had not",
  "hadn't've": "had not have",
  "hasn't": "has not",
  "haven't": "have not",
  "he'd": "he would",
  "he'd've": "he would have",
  "he'll": "he will",
  "he'll've": "he will have",
  "he's": "he is",
  "how'd": "how did",
  "how'd'y": "how do you",
  "how'll": "how will",
  "how's": "how is",
  "i'd": "i would",
  "i'd've": "i would have",
  "i'll": "i will",
  "i'll've": "I will have",
  "i'm": "i am",
  "i've": "i have",
  "isn't": "is not",
  "it'd": "it had",
  "it'd've": "it would have",
  "it'll": "it will",
  "it'll've": "it will have",
  "it's": "it is",
  "let's": "let us",
  "ma'am": "madam",
  "mayn't": "may not",
  "might've": "might have",
  "mightn't": "might not",
  "mightn't've": "might not have",
  "must've": "must have",
  "mustn't": "must not",
  "mustn't've": "must not have",
  "needn't": "need not",
  "needn't've": "need not have",
  "o'clock": "of the clock",
  "oughtn't": "ought not",
  "oughtn't've": "ought not have",
  "shan't": "shall not",
  "sha'n't": "shall not",
  "shan't've": "shall not have",
  "she'd": "she would",
  "she'd've": "she would have",
  "she'll": "she will",
  "she'll've": "she will have",
  "she's": "she is",
  "should've": "should have",
  "shouldn't": "should not",
  "shouldn't've": "should not have",
  "so've": "so have",
  "so's": "so is",
  "that'd": "that would",
  "that'd've": "that would have",
  "that's": "that is",
  "there'd": "there had",
  "there'd've": "there would have",
  "there's": "there is",
  "they'd": "they would",
  "they'd've": "they would have",
  "they'll": "they will",
  "they'll've": "they will have",
  "they're": "they are",
  "they've": "they have",
  "to've": "to have",
  "wasn't": "was not",
  "we'd": "we had",
  "we'd've": "we would have",
  "we'll": "we will",
  "we'll've": "we will have",
  "we're": "we are",
  "we've": "we have",
  "weren't": "were not",
  "what'll": "what will",
  "what'll've": "what will have",
  "what're": "what are",
  "what's": "what is",
  "what've": "what have",
  "when's": "when is",
  "when've": "when have",
  "where'd": "where did",
  "where's": "where is",
  "where've": "where have",
  "who'll": "who will",
  "who'll've": "who will have",
  "who's": "who is",
  "who've": "who have",
  "why's": "why is",
  "why've": "why have",
  "will've": "will have",
  "won't": "will not",
  "won't've": "will not have",
  "would've": "would have",
  "wouldn't": "would not",
  "wouldn't've": "would not have",
  "y'all": "you all",
  "y'alls": "you alls",
  "y'all'd": "you all would",
  "y'all'd've": "you all would have",
  "y'all're": "you all are",
  "y'all've": "you all have",
  "you'd": "you had",
  "you'd've": "you would have",
  "you'll": "you you will",
  "you'll've": "you you will have",
  "you're": "you are",
  "you've": "you have"
}
    
def convertir_contracciones(text):
    t=[]
    words=text.split()
    t = [contracciones[w.lower()] if w.lower() in contracciones.keys() else w for w in words]
    return ' '.join(t) 

df_train['text']=df_train['text'].apply(convertir_contracciones)
df_test['text']=df_test['text'].apply(convertir_contracciones)    



def limpieza(text):
            
    # elimino caracteres especiales
    text = re.sub(r"\x89Û_", "", text)
    text = re.sub(r"\x89ÛÒ", "", text)
    text = re.sub(r"\x89ÛÓ", "", text)
    text = re.sub(r"\x89ÛÏWhen", "When", text)
    text = re.sub(r"\x89ÛÏ", "", text)
    text = re.sub(r"China\x89Ûªs", "China's", text)
    text = re.sub(r"let\x89Ûªs", "let's", text)
    text = re.sub(r"\x89Û÷", "", text)
    text = re.sub(r"\x89Ûª", "", text)
    text = re.sub(r"\x89Û\x9d", "", text)
    text = re.sub(r"å_", "", text)
    text = re.sub(r"\x89Û¢", "", text)
    text = re.sub(r"\x89Û¢åÊ", "", text)
    text = re.sub(r"fromåÊwounds", "from wounds", text)
    text = re.sub(r"åÊ", "", text)
    text = re.sub(r"åÈ", "", text)
    text = re.sub(r"JapÌ_n", "Japan", text)    
    text = re.sub(r"Ì©", "e", text)
    text = re.sub(r"å¨", "", text)
    text = re.sub(r"SuruÌ¤", "Suruc", text)
    text = re.sub(r"åÇ", "", text)
    text = re.sub(r"å£3million", "3 million", text)
    text = re.sub(r"åÀ", "", text)
    
    # Reemplazo contracciones
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"there's", "there is", text)
    text = re.sub(r"We're", "We are", text)
    text = re.sub(r"That's", "That is", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"they're", "they are", text)
    text = re.sub(r"Can't", "Cannot", text)
    text = re.sub(r"wasn't", "was not", text)
    text = re.sub(r"don\x89Ûªt", "do not", text)
    text = re.sub(r"aren't", "are not", text)
    text = re.sub(r"isn't", "is not", text)
    text = re.sub(r"What's", "What is", text)
    text = re.sub(r"haven't", "have not", text)
    text = re.sub(r"hasn't", "has not", text)
    text = re.sub(r"There's", "There is", text)
    text = re.sub(r"He's", "He is", text)
    text = re.sub(r"It's", "It is", text)
    text = re.sub(r"You're", "You are", text)
    text = re.sub(r"I'M", "I am", text)
    text = re.sub(r"shouldn't", "should not", text)
    text = re.sub(r"wouldn't", "would not", text)
    text = re.sub(r"i'm", "I am", text)
    text = re.sub(r"I\x89Ûªm", "I am", text)
    text = re.sub(r"I'm", "I am", text)
    text = re.sub(r"Isn't", "is not", text)
    text = re.sub(r"Here's", "Here is", text)
    text = re.sub(r"you've", "you have", text)
    text = re.sub(r"you\x89Ûªve", "you have", text)
    text = re.sub(r"we're", "we are", text)
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"couldn't", "could not", text)
    text = re.sub(r"we've", "we have", text)
    text = re.sub(r"it\x89Ûªs", "it is", text)
    text = re.sub(r"doesn\x89Ûªt", "does not", text)
    text = re.sub(r"It\x89Ûªs", "It is", text)
    text = re.sub(r"Here\x89Ûªs", "Here is", text)
    text = re.sub(r"who's", "who is", text)
    text = re.sub(r"I\x89Ûªve", "I have", text)
    text = re.sub(r"y'all", "you all", text)
    text = re.sub(r"can\x89Ûªt", "cannot", text)
    text = re.sub(r"would've", "would have", text)
    text = re.sub(r"it'll", "it will", text)
    text = re.sub(r"we'll", "we will", text)
    text = re.sub(r"wouldn\x89Ûªt", "would not", text)
    text = re.sub(r"We've", "We have", text)
    text = re.sub(r"he'll", "he will", text)
    text = re.sub(r"Y'all", "You all", text)
    text = re.sub(r"Weren't", "Were not", text)
    text = re.sub(r"Didn't", "Did not", text)
    text = re.sub(r"they'll", "they will", text)
    text = re.sub(r"they'd", "they would", text)
    text = re.sub(r"DON'T", "DO NOT", text)
    text = re.sub(r"That\x89Ûªs", "That is", text)
    text = re.sub(r"they've", "they have", text)
    text = re.sub(r"i'd", "I would", text)
    text = re.sub(r"should've", "should have", text)
    text = re.sub(r"You\x89Ûªre", "You are", text)
    text = re.sub(r"where's", "where is", text)
    text = re.sub(r"Don\x89Ûªt", "Do not", text)
    text = re.sub(r"we'd", "we would", text)
    text = re.sub(r"i'll", "I will", text)
    text = re.sub(r"weren't", "were not", text)
    text = re.sub(r"They're", "They are", text)
    text = re.sub(r"Can\x89Ûªt", "Cannot", text)
    text = re.sub(r"you\x89Ûªll", "you will", text)
    text = re.sub(r"I\x89Ûªd", "I would", text)
    text = re.sub(r"let's", "let us", text)
    text = re.sub(r"it's", "it is", text)
    text = re.sub(r"can't", "cannot", text)
    text = re.sub(r"don't", "do not", text)
    text = re.sub(r"you're", "you are", text)
    text = re.sub(r"i've", "I have", text)
    text = re.sub(r"that's", "that is", text)
    text = re.sub(r"i'll", "I will", text)
    text = re.sub(r"doesn't", "does not", text)
    text = re.sub(r"i'd", "I would", text)
    text = re.sub(r"didn't", "did not", text)
    text = re.sub(r"ain't", "am not", text)
    text = re.sub(r"you'll", "you will", text)
    text = re.sub(r"I've", "I have", text)
    text = re.sub(r"Don't", "do not", text)
    text = re.sub(r"I'll", "I will", text)
    text = re.sub(r"I'd", "I would", text)
    text = re.sub(r"Let's", "Let us", text)
    text = re.sub(r"you'd", "You would", text)
    text = re.sub(r"It's", "It is", text)
    text = re.sub(r"Ain't", "am not", text)
    text = re.sub(r"Haven't", "Have not", text)
    text = re.sub(r"Could've", "Could have", text)
    text = re.sub(r"youve", "you have", text)  
    text = re.sub(r"donå«t", "do not", text)    
    
    return text


df_train['text']=df_train['text'].apply(lambda x: limpieza(x))
df_test['text']=df_test['text'].apply(lambda x: limpieza(x))

# %%
df_train.loc[500:510]
# Out:
#       id   keyword                        location  \
# 500  725  attacked  LEALMAN, FLORIDA
# 501  726  attacked  Los Angeles, CA
# 502  727  attacked  San Francisco, CA
# 503  728  attacked  #GDJB #ASOT
# 504  729  attacked  Groningen, Netherlands, Europe
# 505  730  attacked  Livingston, IL  U.S.A.
# 506  731  attacked  Arundel
# 507  732  attacked  NaN
# 508  734  attacked  America
# 509  735  attacked  Anna Maria, FL
# 510  736  attacked  USA
#
#                                                                                                                                         text  \
# 500  Christian Attacked by Muslims at the Temple Mount after Waving Israeli Flag via Pamela Geller - ... http://t.co/LHBZHWq4B9
# 501  @envw98 @NickCoCoFree @JulieDiCaro @jdabe80 Why am I the worst person? Questioning how julie attacked him? Do you guys have no empathy?
# 502  Kelly Osbourne attacked for racist Donald Trump remark about Latinos on The View http://t.co/7nAgdSAdWP
# 503  @eunice_njoki aiii she needs to chill and answer calmly its not like she is being attacked
# 504  Christian Attacked by Muslims at the Temple Mount after Waving Israeli Flag via Pamela Geller - ... http://t.co/mXZ7yX8ld1
# 505  Christian Attacked by Muslims at the Temple Mount after Waving Israeli Flag via Pamela Geller - ... http://t.co/e4YDbM4Dx6
# 506  Christian Attacked by Muslims at the Temple Mount after Waving Israeli Flag via Pamela Geller - ... http://t.co/T1aa5Ov7Eg
# 507  I attacked Robot-lvl 19 and i have earned a total of 6615434 free satoshis! http://t.co/DMLJ1aGoTw #robotcoingame #Bitcoin #FreeBitcoin
# 508  Christian Attacked by Muslims at the Temple Mount after Waving Israeli Flag via Pamela Geller - ... http://t.co/EMDJNNltP0
# 509  @christinalavv @lindsay_wynn3 I just saw these tweets and I feel really attacked
# 510  Christian Attacked by Muslims at the Temple Mount after Waving Israeli Flag via Pamela Geller - ... http://t.co/a6wmbnR51S
#
#      target  word_count  unique_word_count  stop_word_count  url_count emails  \
# 500  1       18          18                 4                1          []
# 501  0       21          21                 9                0          []
# 502  1       14          14                 4                1          []
# 503  0       15          15                 8                0          []
# 504  1       18          18                 4                1          []
# 505  1       18          18                 4                1          []
# 506  1       18          18                 4                1          []
# 507  0       17          17                 5                1          []
# 508  1       18          18                 4                1          []
# 509  0       12          11                 5                0          []
# 510  1       18          18                 4                1          []
#
#      emails_count  mean_word_length  char_count  number_count  upper_count  \
# 500  0             5.833333          122         0             0
# 501  0             5.476190          136         0             1
# 502  0             6.428571          103         0             0
# 503  0             5.000000          89          0             0
# 504  0             5.833333          122         0             0
# 505  0             5.833333          122         0             0
# 506  0             5.833333          122         0             0
# 507  0             6.882353          133         2             1
# 508  0             5.833333          122         0             0
# 509  0             5.750000          80          0             2
# 510  0             5.833333          122         0             0
#
#      punctuation_count  hashtag_count  mention_count
# 500  9                  0              0
# 501  7                  0              4
# 502  5                  0              0
# 503  3                  0              1
# 504  9                  0              0
# 505  9                  0              0
# 506  9                  0              0
# 507  11                 3              0
# 508  9                  0              0
# 509  3                  0              2
# 510  9                  0              0

# %%
def eliminacion(text):
    # elimino Retweet RT
    text = re.sub(r'RT', "", text)
    
    # elimino urls
    text = re.sub(r"https?:\/\/t.co\/[A-Za-z0-9]+", "", text)
    
    # elimino puntuaciones
    text = re.sub('[^A-Z a-z 0-9-]+', '', text)
    
    # elimino espacios dobles
    text = re.sub(r"\s+", " ", text)
    
    # convierto a minisculas
    text = text.lower()
    
    
    '''
    # reemplazo caracteres atipicos
    text = re.sub(r"&gt;", " ", text)
    text = re.sub(r"&lt;", " ", text)
    text = re.sub(r"&amp;", " ", text)
    
    # elimino palabras contenidas en []
    text = re.sub('\[.*?\]', '', text)
    
    #Elimino las menciones, hashtag, urls.
    text = re.sub("@|&|#|https?\://\S+|www\.\S+", "", text)
    
    text = re.sub('<.*?>+', '', text)
    
    
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    
    #Elimino numeros y palabras que contengan numeros.
    text = re.sub('\w*\d\w*', '', text)
    
    '''
    
    return text


df_train['text']=df_train['text'].apply(lambda x: eliminacion(x))
df_test['text']=df_test['text'].apply(lambda x: eliminacion(x))

df_train.loc[500:510]
# Out:
#       id   keyword                        location  \
# 500  725  attacked  LEALMAN, FLORIDA
# 501  726  attacked  Los Angeles, CA
# 502  727  attacked  San Francisco, CA
# 503  728  attacked  #GDJB #ASOT
# 504  729  attacked  Groningen, Netherlands, Europe
# 505  730  attacked  Livingston, IL  U.S.A.
# 506  731  attacked  Arundel
# 507  732  attacked  NaN
# 508  734  attacked  America
# 509  735  attacked  Anna Maria, FL
# 510  736  attacked  USA
#
#                                                                                                                                  text  \
# 500  christian attacked by muslims at the temple mount after waving israeli flag via pamela geller -
# 501  envw98 nickcocofree juliedicaro jdabe80 why am i the worst person questioning how julie attacked him do you guys have no empathy
# 502  kelly osbourne attacked for racist donald trump remark about latinos on the view
# 503  eunicenjoki aiii she needs to chill and answer calmly its not like she is being attacked
# 504  christian attacked by muslims at the temple mount after waving israeli flag via pamela geller -
# 505  christian attacked by muslims at the temple mount after waving israeli flag via pamela geller -
# 506  christian attacked by muslims at the temple mount after waving israeli flag via pamela geller -
# 507  i attacked robot-lvl 19 and i have earned a total of 6615434 free satoshis robotcoingame bitcoin freebitcoin
# 508  christian attacked by muslims at the temple mount after waving israeli flag via pamela geller -
# 509  christinalavv lindsaywynn3 i just saw these tweets and i feel really attacked
# 510  christian attacked by muslims at the temple mount after waving israeli flag via pamela geller -
#
#      target  word_count  unique_word_count  stop_word_count  url_count emails  \
# 500  1       18          18                 4                1          []
# 501  0       21          21                 9                0          []
# 502  1       14          14                 4                1          []
# 503  0       15          15                 8                0          []
# 504  1       18          18                 4                1          []
# 505  1       18          18                 4                1          []
# 506  1       18          18                 4                1          []
# 507  0       17          17                 5                1          []
# 508  1       18          18                 4                1          []
# 509  0       12          11                 5                0          []
# 510  1       18          18                 4                1          []
#
#      emails_count  mean_word_length  char_count  number_count  upper_count  \
# 500  0             5.833333          122         0             0
# 501  0             5.476190          136         0             1
# 502  0             6.428571          103         0             0
# 503  0             5.000000          89          0             0
# 504  0             5.833333          122         0             0
# 505  0             5.833333          122         0             0
# 506  0             5.833333          122         0             0
# 507  0             6.882353          133         2             1
# 508  0             5.833333          122         0             0
# 509  0             5.750000          80          0             2
# 510  0             5.833333          122         0             0
#
#      punctuation_count  hashtag_count  mention_count
# 500  9                  0              0
# 501  7                  0              4
# 502  5                  0              0
# 503  3                  0              1
# 504  9                  0              0
# 505  9                  0              0
# 506  9                  0              0
# 507  11                 3              0
# 508  9                  0              0
# 509  3                  0              2
# 510  9                  0              0

# %%
def tokenizacion(text):
    
    tokenizer = nltk.tokenize.RegexpTokenizer(r'\w+')
    tokenizado = tokenizer.tokenize(text)
    sin_stopwords = [w for w in tokenizado if w not in stop_words]
    combinado = ' '.join(sin_stopwords)
    
    return combinado
    
df_train['text']=df_train['text'].apply(lambda x: tokenizacion(x))
df_test['text']=df_test['text'].apply(lambda x: tokenizacion(x))

# %%
df_train.loc[500:510]
# Out:
#       id   keyword                        location  \
# 500  725  attacked  LEALMAN, FLORIDA
# 501  726  attacked  Los Angeles, CA
# 502  727  attacked  San Francisco, CA
# 503  728  attacked  #GDJB #ASOT
# 504  729  attacked  Groningen, Netherlands, Europe
# 505  730  attacked  Livingston, IL  U.S.A.
# 506  731  attacked  Arundel
# 507  732  attacked  NaN
# 508  734  attacked  America
# 509  735  attacked  Anna Maria, FL
# 510  736  attacked  USA
#
#                                                                                              text  \
# 500  christian attacked muslims temple mount waving israeli flag via pamela geller
# 501  envw98 nickcocofree juliedicaro jdabe80 worst person questioning julie attacked guys empathy
# 502  kelly osbourne attacked racist donald trump remark latinos view
# 503  eunicenjoki aiii needs chill answer calmly like attacked
# 504  christian attacked muslims temple mount waving israeli flag via pamela geller
# 505  christian attacked muslims temple mount waving israeli flag via pamela geller
# 506  christian attacked muslims temple mount waving israeli flag via pamela geller
# 507  attacked robot lvl 19 earned total 6615434 free satoshis robotcoingame bitcoin freebitcoin
# 508  christian attacked muslims temple mount waving israeli flag via pamela geller
# 509  christinalavv lindsaywynn3 saw tweets feel really attacked
# 510  christian attacked muslims temple mount waving israeli flag via pamela geller
#
#      target  word_count  unique_word_count  stop_word_count  url_count emails  \
# 500  1       18          18                 4                1          []
# 501  0       21          21                 9                0          []
# 502  1       14          14                 4                1          []
# 503  0       15          15                 8                0          []
# 504  1       18          18                 4                1          []
# 505  1       18          18                 4                1          []
# 506  1       18          18                 4                1          []
# 507  0       17          17                 5                1          []
# 508  1       18          18                 4                1          []
# 509  0       12          11                 5                0          []
# 510  1       18          18                 4                1          []
#
#      emails_count  mean_word_length  char_count  number_count  upper_count  \
# 500  0             5.833333          122         0             0
# 501  0             5.476190          136         0             1
# 502  0             6.428571          103         0             0
# 503  0             5.000000          89          0             0
# 504  0             5.833333          122         0             0
# 505  0             5.833333          122         0             0
# 506  0             5.833333          122         0             0
# 507  0             6.882353          133         2             1
# 508  0             5.833333          122         0             0
# 509  0             5.750000          80          0             2
# 510  0             5.833333          122         0             0
#
#      punctuation_count  hashtag_count  mention_count
# 500  9                  0              0
# 501  7                  0              4
# 502  5                  0              0
# 503  3                  0              1
# 504  9                  0              0
# 505  9                  0              0
# 506  9                  0              0
# 507  11                 3              0
# 508  9                  0              0
# 509  3                  0              2
# 510  9                  0              0

# %% [markdown]
# ## Buscamos palabras comunes

# %%
palabrastrain = ' '.join(df_train['text'])
palabrastrain = palabrastrain.split()

palabrastest = ' '.join(df_test['text'])
palabrastest = palabrastest.split()

frecuenciastrain = pd.Series(palabrastrain).value_counts()
frecuenciastest = pd.Series(palabrastest).value_counts()

display(frecuenciastrain.head(50))
display(frecuenciastest.head(50))
# Out:
# -             779
# like          345
# amp           298
# fire          251
# get           229
# new           226
# via           220
# people        196
# news          194
# one           193
# us            187
# would         175
# video         165
# 2             159
# emergency     157
# disaster      153
# police        141
# still         129
# body          125
# burning       120
# back          119
# crash         119
# california    117
# storm         117
# suicide       116
# time          113
# know          112
# got           112
# buildings     110
# man           110
# day           109
# first         108
# see           105
# bomb          104
# world         103
# going         103
# nuclear       102
# love          101
# cannot        99
# attack        99
# fires         99
# 3             98
# youtube       98
# two           97
# killed        96
# dead          96
# go            96
# train         93
# full          92
# war           91
# dtype: int64
# -            306
# like         145
# amp          136
# fire         107
# get          106
# via          104
# new          102
# would        94
# news         89
# one          84
# people       83
# us           81
# 2            74
# emergency    68
# attack       63
# disaster     61
# first        60
# video        60
# suicide      57
# police       56
# fires        52
# 3            51
# still        50
# watch        50
# storm        49
# time         49
# hiroshima    49
# full         49
# crash        48
# burning      48
# got          48
# two          47
# going        46
# today        45
# body         44
# see          44
# love         44
# know         43
# make         43
# last         43
# go           43
# think        42
# life         41
# 1            40
# buildings    40
# nuclear      40
# world        40
# cannot       39
# forest       39
# bomb         39
# dtype: int64

# %% [markdown]
# ## Intersectamos palabras comunes de ambos target

# %%
#separo por grupos
df_real = df_train[df_train['target']==1]
df_falso = df_train[df_train['target']==0]

palabrasreal = ' '.join(df_real['text'])
palabrasreal = palabrasreal.split()

palabrasfalso = ' '.join(df_falso['text'])
palabrasfalso = palabrasfalso.split()

real35 = pd.Series(palabrasreal).value_counts()[:35]
falso35 = pd.Series(palabrasfalso).value_counts()[:35]

real35 = real35.keys().tolist()
falso35 = falso35.keys().tolist()

elementos_comunes_tipicos = list(set(real35).intersection(set(falso35)))
elementos_comunes_tipicos
# Out:
# ['us',
#  'like',
#  'emergency',
#  'get',
#  '2',
#  'via',
#  'one',
#  'fire',
#  'people',
#  '-',
#  'video',
#  'amp']

# %% [markdown]
# ## Eliminamos estas palabras de ambos sets

# %%
# elimino palabras comunes
def palabras_comunes(text):
    text = " ".join([w for w in text.split() if w not in elementos_comunes_tipicos])
    return text
    
df_train['text']=df_train['text'].apply(lambda x: palabras_comunes(x))
df_test['text']=df_test['text'].apply(lambda x: palabras_comunes(x))

# %%
palabrastrain = ' '.join(df_train['text'])
palabrastrain = palabrastrain.split()

palabrastest = ' '.join(df_test['text'])
palabrastest = palabrastest.split()

frecuenciastrain = pd.Series(palabrastrain).value_counts()
frecuenciastest = pd.Series(palabrastest).value_counts()

display(frecuenciastrain.head(50))
display(frecuenciastest.head(50))
# Out:
# new           226
# news          194
# would         175
# disaster      153
# police        141
# still         129
# body          125
# burning       120
# back          119
# crash         119
# california    117
# storm         117
# suicide       116
# time          113
# got           112
# know          112
# buildings     110
# man           110
# day           109
# first         108
# see           105
# bomb          104
# going         103
# world         103
# nuclear       102
# love          101
# fires         99
# cannot        99
# attack        99
# youtube       98
# 3             98
# two           97
# dead          96
# go            96
# killed        96
# train         93
# full          92
# war           91
# car           90
# good          89
# may           88
# could         88
# families      88
# today         87
# hiroshima     87
# accident      87
# life          87
# think         86
# say           86
# let           86
# dtype: int64
# new           102
# would         94
# news          89
# attack        63
# disaster      61
# first         60
# suicide       57
# police        56
# fires         52
# 3             51
# still         50
# watch         50
# time          49
# storm         49
# hiroshima     49
# full          49
# crash         48
# got           48
# burning       48
# two           47
# going         46
# today         45
# body          44
# love          44
# see           44
# know          43
# last          43
# go            43
# make          43
# think         42
# life          41
# nuclear       40
# world         40
# 1             40
# buildings     40
# could         39
# back          39
# need          39
# even          39
# dead          39
# forest        39
# cannot        39
# bomb          39
# right         38
# youtube       38
# bombing       38
# california    37
# car           37
# day           36
# wild          35
# dtype: int64

# %%
##ver palabras raras###

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV, SGDClassifier
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import f1_score
from sklearn import preprocessing, decomposition, model_selection, metrics, pipeline
from sklearn.model_selection import GridSearchCV,StratifiedKFold,RandomizedSearchCV

# %%
# entrenamiento simple recuento

count_vectorizer = CountVectorizer(min_df=2 ,max_df=0.9, ngram_range=(1, 2))
train_vectors = count_vectorizer.fit_transform(df_train['text'])
test_vectors = count_vectorizer.transform(df_test['text'])

# %%
# Fitting a simple Naive Bayes on Counts
clf_NB = MultinomialNB()
scores = model_selection.cross_val_score(clf_NB, train_vectors, df_train["target"], cv=5, scoring="f1")
scores
# Out:
# array([0.59000943, 0.57928803, 0.63225806, 0.61417323, 0.74475777])

# %%
# modelo Logistic Regression recuento
clf = LogisticRegression(C=1.0)
scores = model_selection.cross_val_score(clf, train_vectors, df_train['target'], cv=5, scoring="f1")
scores

#v2 array([0.59827421, 0.48601399, 0.55480607, 0.49665712, 0.68870968]) mejor
# con limpieza 2 array([0.58981748, 0.50902837, 0.55148342, 0.51643192, 0.68803753])
# sin limpieza array([0.60114504, 0.48378615, 0.5655058 , 0.51943128, 0.6963434 ])

# probar ngram(1,1)
#array([0.60338346, 0.49913644, 0.55980066, 0.51180359, 0.68970935])
# Out:
# array([0.60338346, 0.49913644, 0.55980066, 0.51180359, 0.68970935])

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

tfidf = TfidfVectorizer(min_df=2, max_df=0.5, ngram_range=(1, 1))
tfidf_train = tfidf.fit_transform(df_train['text'])

# %%
# entreno con Logistic Regresion y TF-IDF
clf_tfidf = LogisticRegression(C=1.0)
scores = model_selection.cross_val_score(clf_tfidf, tfidf_train, df_train['target'], cv=5, scoring="f1")
scores

# con limpieza 2 array([0.54845361, 0.463138  , 0.5093046 , 0.47167868, 0.66079295])
# sin limpieza array([0.56880734, 0.48210923, 0.5369863 , 0.45168067, 0.66311111])
# ngramas 1,1 array([0.58541459, 0.50686185, 0.5419708 , 0.50901804, 0.69296741])
# Out:
# array([0.58541459, 0.50686185, 0.5419708 , 0.50901804, 0.69296741])

# %%
# Fitting a simple Naive Bayes on Counts
clf_NB = MultinomialNB()
scores = model_selection.cross_val_score(clf_NB, train_vectors, df_train["target"], cv=5, scoring="f1")
scores

# probar array([0.61818182, 0.60692771, 0.67601476, 0.63355049, 0.7303989 ])
# Out:
# array([0.61818182, 0.60692771, 0.67601476, 0.63355049, 0.7303989 ])

# %%
# Fitting a simple Naive Bayes on TFIDF
clf_NB_TFIDF = MultinomialNB()
scores = model_selection.cross_val_score(clf_NB_TFIDF, tfidf_train, df_train["target"], cv=5, scoring="f1")
scores

# sin limpieza array([0.56573705, 0.57193606, 0.59090909, 0.582397  , 0.73968254])
# ngramas 1,1 array([0.60528715, 0.61387755, 0.64395783, 0.61028771, 0.75353686])
# Out:
# array([0.60528715, 0.61387755, 0.64395783, 0.61028771, 0.75353686])

# %%
#v1 array([0.57471264, 0.47579299, 0.57738573, 0.54561879, 0.68725869])
#v2 array([0.59827421, 0.48601399, 0.55480607, 0.49665712, 0.68870968])

#array([0.62846227, 0.53043478, 0.61359867, 0.56859206, 0.71221865])
#array([0.60731949, 0.48692516, 0.57931034, 0.522158  , 0.6980198 ])
# Out:
# array([0.5986654 , 0.47776809, 0.56213511, 0.50332384, 0.69446672])

# %% [markdown]
# ## Modelo definitivo de esta version

# %%
tfidf = TfidfVectorizer(min_df=2, max_df=0.5, ngram_range=(1, 1))

tfidf_train = tfidf.fit_transform(df_train['text'])
tfidf_test = tfidf.transform(df_test['text'])

# %%
clf_NB_TFIDF = MultinomialNB()
scores = model_selection.cross_val_score(clf_NB_TFIDF, tfidf_train, df_train["target"], cv=5, scoring="f1")
scores

array([0.61818182, 0.60692771, 0.67601476, 0.63355049, 0.7303989 ])
# Out:
# array([0.60528715, 0.61387755, 0.64395783, 0.61028771, 0.75353686])

# %%
# entreno logistic regresion con tfidf con ngramas (1,1)

clf_NB_TFIDF.fit(tfidf_train, df_train["target"])
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
# Submission
sample_submission = pd.read_csv("dataset/sample_submission.csv")
sample_submission['target'] = clf_NB_TFIDF.predict(tfidf_test)
sample_submission.to_csv("submission8.csv", index=False)

# %%
## lo que falto

# %%
import spacy
import gensim
import gensim.downloader as api
wv = api.load('word2vec-google-news-300')

# %%
import gc
del wv
gc.collect()
# Out:
# 0

# %%
from tqdm import tqdm

# %%
def crear_corpus(df):
    corpus=[]
    for tweet in tqdm(df['text']):
        words=[word.lower() for word in word_tokenize(tweet) if((word.isalpha()==1) & (word not in stop_words))]
        corpus.append(words)
    return corpus

# %%
corpus=crear_corpus(df_train)
# Out:
# 100%|██████████| 7613/7613 [00:02<00:00, 2682.52it/s]

# %%
corpus
# Out:
# [['deeds', 'reason', 'earthquake', 'may', 'allah', 'forgive'],
#  ['forest', 'near', 'la', 'ronge', 'sask', 'canada'],
#  ['residents',
#   'asked',
#   'shelter',
#   'place',
#   'notified',
#   'officers',
#   'evacuation',
#   'shelter',
#   'place',
#   'orders',
#   'expected'],
#  ['receive', 'wildfires', 'evacuation', 'orders', 'california'],
#  ['got',
#   'sent',
#   'photo',
#   'ruby',
#   'alaska',
#   'smoke',
#   'wildfires',
#   'pours',
#   'school'],
#  ['rockyfire',
#   'update',
#   'california',
#   'hwy',
#   'closed',
#   'directions',
#   'due',
#   'lake',
#   'county',
#   'cafire',
#   'wildfires'],
#  ['flood',
#   'disaster',
#   'heavy',
#   'rain',
#   'causes',
#   'flash',
#   'flooding',
#   'streets',
#   'manitou',
#   'colorado',
#   'springs',
#   'areas'],
#  ['top', 'hill', 'see', 'woods'],
#  ['evacuation', 'happening', 'building', 'across', 'street'],
#  ['afraid', 'tornado', 'coming', 'area'],
#  ['three', 'died', 'heat', 'wave', 'far'],
#  ['haha',
#   'south',
#   'tampa',
#   'getting',
#   'flooded',
#   'wait',
#   'second',
#   'live',
#   'south',
#   'tampa',
#   'gon',
#   'na',
#   'gon',
#   'na',
#   'fvck',
#   'flooding'],
#  ['raining',
#   'flooding',
#   'florida',
#   'tampabay',
#   'tampa',
#   'days',
#   'lost',
#   'count'],
#  ['flood', 'bago', 'myanmar', 'arrived', 'bago'],
#  ['damage', 'school', 'bus', 'multi', 'car', 'crash', 'breaking'],
#  ['man'],
#  ['love', 'fruits'],
#  ['summer', 'lovely'],
#  ['car', 'fast'],
#  ['goooooooaaaaaal'],
#  ['ridiculous'],
#  ['london', 'cool'],
#  ['love', 'skiing'],
#  ['wonderful', 'day'],
#  ['looooool'],
#  ['wayi', 'eat', 'shit'],
#  ['nyc', 'last', 'week'],
#  ['love', 'girlfriend'],
#  ['cooool'],
#  ['pasta'],
#  ['end'],
#  ['bbcmtd', 'wholesale', 'markets', 'ablaze'],
#  ['always', 'try', 'bring', 'heavy', 'metal'],
#  ['africanbaze', 'breaking', 'newsnigeria', 'flag', 'set', 'ablaze', 'aba'],
#  ['crying', 'set', 'ablaze'],
#  ['plus', 'side', 'look', 'sky', 'last', 'night', 'ablaze'],
#  ['phdsquares',
#   'mufc',
#   'built',
#   'much',
#   'hype',
#   'around',
#   'new',
#   'acquisitions',
#   'doubt',
#   'set',
#   'epl',
#   'ablaze',
#   'season'],
#  ['inec', 'office', 'abia', 'set', 'ablaze'],
#  ['barbados',
#   'bridgetown',
#   'jamaica',
#   'two',
#   'cars',
#   'set',
#   'ablaze',
#   'santa',
#   'cruz',
#   'head',
#   'st',
#   'elizabeth',
#   'police',
#   'superintende'],
#  ['ablaze', 'lord'],
#  ['check', 'nsfw'],
#  ['outside', 'ablaze', 'alive', 'dead', 'inside'],
#  ['awesome',
#   'time',
#   'visiting',
#   'cfc',
#   'head',
#   'office',
#   'ancop',
#   'site',
#   'ablaze',
#   'thanks',
#   'tita',
#   'vida',
#   'taking',
#   'care'],
#  ['soooo', 'pumped', 'ablaze', 'southridgelife'],
#  ['wanted', 'set', 'chicago', 'ablaze', 'preaching', 'hotel'],
#  ['gained', 'followers', 'last', 'week', 'know', 'stats', 'grow'],
#  ['west', 'burned', 'thousands', 'wildfires', 'ablaze', 'california', 'alone'],
#  ['building', 'perfect', 'tracklist', 'life', 'leave', 'streets', 'ablaze'],
#  ['check', 'nsfw'],
#  ['first',
#   'night',
#   'retainers',
#   'quite',
#   'weird',
#   'better',
#   'used',
#   'wear',
#   'every',
#   'single',
#   'night',
#   'next',
#   'year',
#   'least'],
#  ['deputies', 'man', 'shot', 'brighton', 'home', 'set', 'ablaze'],
#  ['man', 'wife', 'six', 'years', 'jail', 'setting', 'ablaze', 'niece'],
#  ['santa',
#   'cruz',
#   'head',
#   'st',
#   'elizabeth',
#   'police',
#   'superintendent',
#   'lanford',
#   'salmon',
#   'r'],
#  ['police',
#   'arsonist',
#   'deliberately',
#   'set',
#   'black',
#   'church',
#   'north',
#   'carolinaablaze'],
#  ['noches',
#   'alexissanchez',
#   'happy',
#   'see',
#   'teammates',
#   'training',
#   'hard',
#   'goodnight',
#   'gunners'],
#  ['kurds',
#   'trampling',
#   'turkmen',
#   'flag',
#   'later',
#   'set',
#   'ablaze',
#   'others',
#   'vandalized',
#   'offices',
#   'turkmen',
#   'front',
#   'diyala'],
#  ['truck',
#   'ablaze',
#   'voorekker',
#   'ave',
#   'outside',
#   'tambo',
#   'intl',
#   'cargo',
#   'section'],
#  ['set',
#   'hearts',
#   'ablaze',
#   'every',
#   'city',
#   'gift',
#   'every',
#   'skyline',
#   'kiss',
#   'upon',
#   'lips'],
#  ['sky',
#   'ablaze',
#   'tonight',
#   'los',
#   'angeles',
#   'expecting',
#   'ig',
#   'fb',
#   'filled',
#   'sunset',
#   'shots',
#   'know',
#   'peeps'],
#  ['west',
#   'burned',
#   'thousands',
#   'wildfires',
#   'ablaze',
#   'california',
#   'alone',
#   'climate',
#   'energy'],
#  ['revel',
#   'wmv',
#   'videos',
#   'means',
#   'mac',
#   'farewell',
#   'ablaze',
#   'wmv',
#   'en',
#   'route',
#   'dvd',
#   'gtxrwm'],
#  ['progressive',
#   'greetings',
#   'month',
#   'students',
#   'would',
#   'set',
#   'pens',
#   'ablaze',
#   'torch',
#   'publications'],
#  ['rene', 'ablaze', 'jacinta', 'secret', 'fallen', 'skies', 'edit', 'mar'],
#  ['steve',
#   'fires',
#   'something',
#   'else',
#   'california',
#   'tinderbox',
#   'clown',
#   'setting',
#   'hood',
#   'ablaze'],
#  ['nowplaying', 'rene', 'ablaze', 'ian', 'buff', 'magnitude', 'edm'],
#  ['nxwestmidlands', 'huge', 'wholesale', 'markets', 'ablaze'],
#  ['ablaze', 'time', 'talk', 'go', 'know', 'make', 'due', 'work'],
#  ['kids',
#   'cuz',
#   'got',
#   'bicycle',
#   'accident',
#   'split',
#   'testicles',
#   'impossible',
#   'kids',
#   'michael',
#   'father'],
#  ['accident', 'w', 'nashvilletraffic', 'traffic', 'moving', 'slower', 'usual'],
#  ['accident',
#   'center',
#   'lane',
#   'blocked',
#   'santaclara',
#   'nb',
#   'great',
#   'america',
#   'pkwy',
#   'bayarea',
#   'traffic'],
#  ['personalinjury',
#   'accident',
#   'summer',
#   'read',
#   'advice',
#   'see',
#   'solicitor',
#   'help',
#   'otleyhour'],
#  ['stlouis',
#   'caraccidentlawyer',
#   'speeding',
#   'among',
#   'top',
#   'causes',
#   'teen',
#   'accidents',
#   'car',
#   'accident',
#   'tee'],
#  ['reported',
#   'motor',
#   'vehicle',
#   'accident',
#   'curry',
#   'herman',
#   'rd',
#   'near',
#   'stephenson',
#   'involving',
#   'overturned',
#   'vehicle',
#   'please',
#   'use'],
#  ['bigrigradio', 'live', 'accident', 'awareness'],
#  ['mile',
#   'marker',
#   'south',
#   'mooresville',
#   'iredell',
#   'vehicle',
#   'accident',
#   'ramp',
#   'closed',
#   'pm'],
#  ['sleepjunkies', 'sleeping', 'pills', 'double', 'risk', 'car', 'accident'],
#  ['accident', 'knew', 'gon', 'happen'],
#  ['traffic', 'accident', 'n', 'cabrillo', 'hwymagellan', 'av', 'mir'],
#  ['mile',
#   'marker',
#   'south',
#   'mooresville',
#   'iredell',
#   'vehicle',
#   'accident',
#   'congestion',
#   'pm'],
#  ['pastor', 'scene', 'accidentwho', 'owner', 'range', 'rover'],
#  ['mom',
#   'home',
#   'fast',
#   'wished',
#   'mom',
#   'accident',
#   'truck',
#   'spilt',
#   'mayonnaise'],
#  ['horrible',
#   'car',
#   'accident',
#   'past',
#   'sunday',
#   'finally',
#   'able',
#   'around',
#   'thank',
#   'god'],
#  ['wait', 'see', 'pissed', 'donnie', 'tell', 'another', 'accident'],
#  ['truckcrash', 'overturns', 'fortworth', 'interstate', 'click', 'crashgt'],
#  ['accident', 'ashville', 'sb', 'sr', 'traffic'],
#  ['carolina',
#   'accident',
#   'motorcyclist',
#   'dies',
#   'crash',
#   'car',
#   'crossed',
#   'median',
#   'motorcycle',
#   'rider',
#   'traveling'],
#  ['fyi', 'cadfyi', 'accident', 'propey', 'piner', 'rdhorndale', 'dr'],
#  ['naayf',
#   'first',
#   'accident',
#   'years',
#   'turning',
#   'onto',
#   'chandanee',
#   'magu',
#   'near',
#   'mma',
#   'taxi',
#   'rammed',
#   'halfway',
#   'turned',
#   'everyone',
#   'conf'],
#  ['accident',
#   'left',
#   'lane',
#   'blocked',
#   'manchester',
#   'rt',
#   'nb',
#   'eddy',
#   'rd',
#   'stop',
#   'go',
#   'traffic',
#   'back',
#   'delay',
#   'mins',
#   'traffic'],
#  ['accident', 'propey', 'damage', 'piner', 'rdhorndale', 'dr'],
#  ['accident'],
#  ['fyi', 'cadfyi', 'accident', 'propey', 'st'],
#  ['pm', 'traffic', 'accident', 'injury', 'willis', 'foreman', 'rd'],
#  ['aashiqui', 'actress', 'anu', 'aggarwal', 'accident'],
#  ['suffield', 'alberta', 'accident'],
#  ['mile',
#   'backup',
#   'southaccident',
#   'blocking',
#   'right',
#   'lanes',
#   'exit',
#   'langtree',
#   'rdconsider',
#   'nc',
#   'nc',
#   'nc',
#   'alternate'],
#  ['accident',
#   'changed',
#   'life',
#   'help',
#   'determine',
#   'options',
#   'financially',
#   'support',
#   'life',
#   'care',
#   'plans',
#   'treatment'],
#  ['breaking',
#   'deadly',
#   'motorcycle',
#   'car',
#   'accident',
#   'happened',
#   'hagerstown',
#   'today',
#   'details',
#   'whag'],
#  ['flowri', 'marinading', 'accident'],
#  ['car',
#   'even',
#   'week',
#   'got',
#   'fucking',
#   'car',
#   'accident',
#   'mfs',
#   'fucking',
#   'drive'],
#  ['norwaymfa',
#   'bahrain',
#   'police',
#   'previously',
#   'died',
#   'road',
#   'accident',
#   'killed',
#   'explosion'],
#  ['still',
#   'heard',
#   'church',
#   'leaders',
#   'kenya',
#   'coming',
#   'forward',
#   'comment',
#   'accident',
#   'issue',
#   'disciplinary',
#   'measuresarrestpastornganga'],
#  ['aftershockdelo', 'scuf', 'ps', 'live', 'game', 'cya'],
#  ['man',
#   'drive',
#   'effort',
#   'gets',
#   'painful',
#   'man',
#   'win',
#   'roger',
#   'bannister'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance',
#   'ices'],
#  ['victory', 'bargain', 'basement', 'prices', 'dwight', 'david', 'eisenhower'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance',
#   'ices'],
#  ['nobody', 'remembers', 'came', 'second', 'charles', 'schulz'],
#  ['aftershockdelo',
#   'im',
#   'speaking',
#   'someone',
#   'using',
#   'scuf',
#   'end',
#   'getting',
#   'ps',
#   'also'],
#  ['harder', 'conflict', 'glorious', 'triumph', 'thomas', 'paine'],
#  ['growingupspoiled',
#   'going',
#   'clay',
#   'pigeon',
#   'shooting',
#   'crying',
#   'aftershock'],
#  ['guess', 'actually', 'wants', 'free', 'aftershock', 'tc'],
#  ['aftershock',
#   'terrifying',
#   'best',
#   'roller',
#   'coaster',
#   'ever',
#   'disclaimer'],
#  ['aftershock'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance',
#   'ices'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance',
#   'ices'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance',
#   'ices'],
#  ['kjfordays', 'seeing', 'issues', 'aftershock'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance',
#   'ices'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance',
#   'ices'],
#  ['wisdomwed',
#   'bonus',
#   'minute',
#   'daily',
#   'habits',
#   'could',
#   'really',
#   'improve',
#   'life',
#   'many',
#   'already',
#   'lifehacks'],
#  ['aftershock',
#   'protect',
#   'profit',
#   'next',
#   'global',
#   'financial',
#   'meltdown',
#   'david',
#   'wiedemer',
#   'http'],
#  ['moment',
#   'scary',
#   'roller',
#   'coaster',
#   'guy',
#   'behind',
#   'screaming',
#   'bloody',
#   'murder',
#   'silverwood',
#   'aftershock'],
#  ['aftershock', 'full', 'streaming', 'youtube'],
#  ['gtgt',
#   'aftershock',
#   'protect',
#   'profit',
#   'next',
#   'global',
#   'financial',
#   'book',
#   'esquireattire'],
#  ['sometimes',
#   'face',
#   'difficulties',
#   'something',
#   'wrong',
#   'something',
#   'right',
#   'joel',
#   'osteen'],
#  ['thing',
#   'stands',
#   'dream',
#   'try',
#   'belief',
#   'actually',
#   'possible',
#   'joel',
#   'brown'],
#  ['praise', 'god', 'ministry', 'tells', 'wdyouth', 'biblestudy'],
#  ['remembering',
#   'going',
#   'die',
#   'best',
#   'way',
#   'know',
#   'avoid',
#   'trap',
#   'thinking',
#   'something',
#   'lose',
#   'steve',
#   'jobs'],
#  ['tried', 'orange', 'aftershock', 'today', 'life', 'never'],
#  ['onfireanders', 'love', 'bb'],
#  ['aftershock'],
#  ['aftershock',
#   'back',
#   'school',
#   'kick',
#   'great',
#   'want',
#   'thank',
#   'everyone',
#   'making',
#   'possible',
#   'great',
#   'night'],
#  ['say', 'done', 'interrupt', 'george', 'bernard', 'shaw'],
#  ['first',
#   'man',
#   'gets',
#   'oyster',
#   'second',
#   'man',
#   'gets',
#   'shell',
#   'andrew',
#   'carnegie'],
#  ['anyone',
#   'need',
#   'pu',
#   'tonight',
#   'play',
#   'hybrid',
#   'slayer',
#   'eu',
#   'hmu',
#   'empirikgaming',
#   'codawscrims',
#   'aftershockorg'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'news'],
#  ['strict',
#   'liability',
#   'context',
#   'airplane',
#   'accident',
#   'pilot',
#   'error',
#   'common',
#   'component',
#   'aviation',
#   'cr'],
#  ['crobscarla', 'lifetime', 'odds', 'dying', 'airplane', 'accident'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'wedn'],
#  ['alexalltimelow',
#   'awwww',
#   'airplane',
#   'accident',
#   'gon',
#   'na',
#   'die',
#   'cuties',
#   'good',
#   'job'],
#  ['family',
#   'members',
#   'osama',
#   'bin',
#   'laden',
#   'died',
#   'airplane',
#   'accident',
#   'ironic',
#   'mhmmm',
#   'gov',
#   'shit',
#   'suspect'],
#  ['man', 'goes', 'airplane', 'engine', 'accident', 'youtube'],
#  ['horrible', 'accident', 'man', 'died', 'wings', 'airplane'],
#  ['cessna',
#   'airplane',
#   'accident',
#   'ocampo',
#   'coahuila',
#   'mexico',
#   'july',
#   'killed',
#   'four',
#   'men',
#   'including',
#   'state',
#   'coahuila',
#   'government',
#   'official'],
#  ['horrible', 'accident', 'man', 'died', 'wings', 'airplane', 'watchthevideo'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'wednesday'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'wednesday',
#   'began',
#   'examining'],
#  ['kca',
#   'mbataweel',
#   'rip',
#   'binladen',
#   'family',
#   'members',
#   'killed',
#   'airplanes',
#   'accident'],
#  ['almost',
#   'sent',
#   'coworker',
#   'nudes',
#   'accident',
#   'thank',
#   'god',
#   'airplane',
#   'mode'],
#  ['mickinyman',
#   'theatlantic',
#   'might',
#   'killed',
#   'airplane',
#   'accident',
#   'night',
#   'car',
#   'wreck',
#   'politics',
#   'best'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'mlb'],
#  ['unbelievably',
#   'insane',
#   'man',
#   'airport',
#   'airplane',
#   'aircraft',
#   'aeroplane',
#   'runway',
#   'accident',
#   'freaky'],
#  ['horrible', 'accident', 'man', 'died', 'wings'],
#  ['horrible', 'accident', 'man', 'died', 'wings', 'airplane'],
#  ['usama',
#   'bin',
#   'ladins',
#   'family',
#   'dead',
#   'airplane',
#   'crash',
#   'naturally',
#   'accident'],
#  ['pilot',
#   'dies',
#   'plane',
#   'crash',
#   'car',
#   'festival',
#   'youtube',
#   'crash',
#   'aircraft',
#   'airplane',
#   'pilot',
#   'death',
#   'accident',
#   'carfest'],
#  ['strict', 'liability', 'context', 'airplane', 'accident'],
#  ['dtn',
#   'brazil',
#   'experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'exp'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'wedn'],
#  ['horrible',
#   'accident',
#   'man',
#   'died',
#   'wings',
#   'airplane',
#   'wtf',
#   'cant',
#   'believe',
#   'eyes'],
#  ['nicole',
#   'fletcher',
#   'victim',
#   'crashed',
#   'airplane',
#   'times',
#   'ago',
#   'accident',
#   'left',
#   'little',
#   'bit',
#   'trauma',
#   'although'],
#  ['omg', 'horrible', 'accident', 'man', 'died', 'wings', 'airplane'],
#  ['omg',
#   'believe',
#   'rip',
#   'bro',
#   'airplane',
#   'accident',
#   'jetengine',
#   'turbojet',
#   'boing'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'wednesday',
#   'began',
#   'examining'],
#  ['airplane', 'accident'],
#  ['phone', 'looks', 'car', 'ship', 'airplane', 'accident', 'terrible'],
#  ['statistically',
#   'risk',
#   'getting',
#   'killed',
#   'cop',
#   'dying',
#   'airplane',
#   'accident'],
#  ['airplane', 'crashes', 'house', 'colombia', 'die', 'accident'],
#  ['shooting', 'airplane', 'accident'],
#  ['could',
#   'drone',
#   'cause',
#   'airplane',
#   'accident',
#   'pilots',
#   'worried',
#   'use',
#   'drones',
#   'esp',
#   'close',
#   'vicinity',
#   'airports'],
#  ['early',
#   'wake',
#   'call',
#   'sister',
#   'begging',
#   'come',
#   'ride',
#   'wher',
#   'ambulance',
#   'hospital',
#   'rodkiai'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['two',
#   'air',
#   'ambulances',
#   'scene',
#   'serious',
#   'crash',
#   'two',
#   'cars',
#   'lorry',
#   'emsne'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'reuters',
#   'yugvani'],
#  ['leading', 'services', 'boss', 'welcomes', 'new', 'ambulance', 'charity'],
#  ['anyone',
#   'travelling',
#   'right',
#   'incident',
#   'services',
#   'halt',
#   'outside',
#   'shrews',
#   'ambulance',
#   'scene'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['ambulance',
#   'sprinter',
#   'automatic',
#   'frontline',
#   'vehicle',
#   'choice',
#   'lez',
#   'compliant',
#   'ebay'],
#  ['new', 'nanotech', 'device', 'able', 'target', 'destroy', 'blood', 'clots'],
#  ['hella', 'crazy', 'fights', 'ambulance', 'couple', 'mosh', 'pits'],
#  ['run', 'ambulance', 'lucky', 'justsaying', 'randomthought'],
#  ['news',
#   'twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'tilnow',
#   'dna'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['tanslash', 'waiting', 'ambulance'],
#  ['fouseytube', 'ok', 'need', 'ambulance', 'hahahah', 'good'],
#  ['ambulance',
#   'sprinter',
#   'automatic',
#   'frontline',
#   'vehicle',
#   'choice',
#   'lez',
#   'compliant',
#   'ebay'],
#  ['pakistan', 'air', 'ambulance', 'helicopter', 'crash', 'kills', 'nine'],
#  ['thenissonian',
#   'rejectdcartoons',
#   'nissan',
#   'ok',
#   'need',
#   'medical',
#   'assistance',
#   'call',
#   'ambulance',
#   'need'],
#  ['ny',
#   'emts',
#   'petition',
#   'per',
#   'hour',
#   'minimum',
#   'wage',
#   'ems',
#   'paramedics',
#   'ambulance'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['ambulance',
#   'sprinter',
#   'automatic',
#   'frontline',
#   'vehicle',
#   'choice',
#   'lez',
#   'compliant',
#   'ebay'],
#  ['ambulance',
#   'sprinter',
#   'automatic',
#   'frontline',
#   'vehicle',
#   'choice',
#   'lez',
#   'compliant',
#   'ebay'],
#  ['kiwikaryn',
#   'check',
#   'parking',
#   'lot',
#   'said',
#   'last',
#   'year',
#   'ambulance',
#   'st',
#   'johns'],
#  ['know', 'way', 'ambulance', 'coming', 'ltlt'],
#  ['reuters',
#   'twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['ambulance', 'right', 'outside', 'work'],
#  ['leoblakecarter', 'dog', 'thinks', 'ambulance', 'natasharideout'],
#  ['happening', 'hatzolah', 'ems', 'ambulance', 'responding', 'dual', 'sirens'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'worldnews'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'worldnews'],
#  ['police', 'ambulance', 'number', 'lesotho', 'body', 'know'],
#  ['aaceorg',
#   'surprised',
#   'still',
#   'standardised',
#   'clinical',
#   'practice',
#   'across',
#   'nhs',
#   'ambulance',
#   'trust'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['try', 'ambulance', 'passing', 'hate'],
#  ['episode',
#   'trunks',
#   'annihilated',
#   'freiza',
#   'cleanest',
#   'shit',
#   'ever',
#   'showed',
#   'nigga',
#   'mercy'],
#  ['shall',
#   'annihilated',
#   'petebests',
#   'dessicated',
#   'laid',
#   'bare',
#   'shall',
#   'kneel'],
#  ['uribe', 'annihilated', 'baseball', 'mets'],
#  ['marksmaponyane',
#   'heysundowns',
#   'annihilated',
#   'previous',
#   'meeting',
#   'celticindeed',
#   'improvement'],
#  ['tneazzy',
#   'mizzou',
#   'annihilated',
#   'florida',
#   'past',
#   'seasons',
#   'even',
#   'ended',
#   'muschamps',
#   'career',
#   'compete',
#   'bama'],
#  ['annihilated', 'abs'],
#  ['annihilated',
#   'status',
#   'education',
#   'mba',
#   'behalf',
#   'easy',
#   'street',
#   'careen',
#   'eovm'],
#  ['luka', 'die', 'everything', 'annihilated', 'alois', 'trancy'],
#  ['acarewornheart', 'good', 'un', 'fella', 'sorry', 'annihilated'],
#  ['cop',
#   'pulls',
#   'drunk',
#   'driver',
#   'safety',
#   'seconds',
#   'car',
#   'hit',
#   'train',
#   'viralspell'],
#  ['must', 'annihilated'],
#  ['cop',
#   'pulls',
#   'drunk',
#   'driver',
#   'safety',
#   'seconds',
#   'car',
#   'hit',
#   'train',
#   'viralspell'],
#  ['boom', 'country', 'entirely', 'annihilated', 'h', 'britain'],
#  ['amirkingkhan',
#   'would',
#   'annihilated',
#   'might',
#   'well',
#   'thank',
#   'floydmayweather'],
#  ['thing',
#   'promised',
#   'israel',
#   'annihilated',
#   'butthe',
#   'horror',
#   'iran',
#   'wnukes'],
#  ['violentfeminazi',
#   'guess',
#   'ok',
#   'armenians',
#   'since',
#   'spent',
#   'history',
#   'getting',
#   'annihilated'],
#  ['years',
#   'since',
#   'annihilated',
#   'instantly',
#   'became',
#   'aware',
#   'ability',
#   'annihilate',
#   'whole',
#   'humanity'],
#  ['day',
#   'tryouts',
#   'went',
#   'good',
#   'minus',
#   'fact',
#   'stopped',
#   'quickly',
#   'short',
#   'ball',
#   'annihilated',
#   'toenail',
#   'injury',
#   'even'],
#  ['oryx', 'symbol', 'arabian', 'peninsula', 'annihilated', 'hunters'],
#  ['luka', 'die', 'everything', 'annihilated', 'alois', 'trancy'],
#  ['ready', 'annihilated', 'bucs', 'game'],
#  ['philipduncan',
#   'breakfastone',
#   'annihilated',
#   'last',
#   'nights',
#   'weather',
#   'really',
#   'philip',
#   'thought',
#   'would',
#   'forecast'],
#  ['domain', 'sophistication', 'annihilated', 'closely', 'feat', 'zrnf'],
#  ['stormbeard',
#   'steellord',
#   'seen',
#   'judas',
#   'priest',
#   'rob',
#   'came',
#   'back',
#   'scorpions',
#   'support',
#   'fucking',
#   'annihilated',
#   'place',
#   'astonishing',
#   'gig'],
#  ['officially',
#   'skipping',
#   'hashtag',
#   'getting',
#   'annihilated',
#   'reviews',
#   'bummer'],
#  ['tomcatarts',
#   'thus',
#   'explaining',
#   'annihilated',
#   'case',
#   'survivor',
#   'evolved',
#   'became',
#   'godlike'],
#  ['completely', 'annihilated', 'cech', 'paul', 'keegan', 'time', 'alive'],
#  ['tomcatarts',
#   'annihilated',
#   'legion',
#   'survivors',
#   'imperfect',
#   'hybrid',
#   'project',
#   'quickly',
#   'formed',
#   'new',
#   'secret',
#   'cell'],
#  ['sirbrandonknt',
#   'exactly',
#   'lesnarcena',
#   'match',
#   'summerslam',
#   'last',
#   'year',
#   'great',
#   'brock',
#   'annihilated',
#   'guy'],
#  ['cop',
#   'pulls',
#   'drunk',
#   'driver',
#   'safety',
#   'seconds',
#   'car',
#   'hit',
#   'train',
#   'viralspell'],
#  ['annihilated',
#   'damascus',
#   'syrian',
#   'army',
#   'grinds',
#   'alloosh',
#   'gang',
#   'manure',
#   'pile'],
#  ['thatdes',
#   'ok',
#   'completely',
#   'forthright',
#   'may',
#   'also',
#   'food',
#   'coma',
#   'bc',
#   'kebabtahinipickles',
#   'also',
#   'annihilated',
#   'wfries'],
#  ['fun',
#   'filled',
#   'simmons',
#   'bar',
#   'camden',
#   'handsome',
#   'got',
#   'annihilated',
#   'apart',
#   'game'],
#  ['juanny', 'beisbol', 'sr', 'annihilated', 'ball', 'lgm'],
#  ['rvfriedmann',
#   'hell',
#   'fraction',
#   'belief',
#   'total',
#   'annihilation',
#   'destruction',
#   'usa',
#   'lodisilverado',
#   'ritzyjewels'],
#  ['potus',
#   'maybe',
#   'call',
#   'israel',
#   'tell',
#   'sorry',
#   'pres',
#   'sold',
#   'river',
#   'annihilation'],
#  ['evildead', 'annihilation', 'civilization'],
#  ['national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'change'],
#  ['annihilating', 'quarterstaff', 'annihilation'],
#  ['world',
#   'annihilation',
#   'vs',
#   'self',
#   'transformation',
#   'aliens',
#   'attack',
#   'exterminate',
#   'humans'],
#  ['starmade', 'stardate', 'planetary', 'annihilation', 'youtube'],
#  ['national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'change'],
#  ['national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'change'],
#  ['kimkardashian',
#   'please',
#   'sign',
#   'share',
#   'petition',
#   'save',
#   'wild',
#   'horses',
#   'arizona'],
#  ['national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'change'],
#  ['theellenshow',
#   'please',
#   'check',
#   'salt',
#   'river',
#   'horses',
#   'help',
#   'stop',
#   'annihilation',
#   'happen',
#   'without',
#   'signatureschange',
#   'org',
#   'thx'],
#  ['souls', 'punished', 'withannihilation'],
#  ['calfreedommom',
#   'mention',
#   'major',
#   'contributor',
#   'annihilation',
#   'israel'],
#  ['willienelson',
#   'need',
#   'help',
#   'horses',
#   'dieplease',
#   'sign',
#   'petitiontake',
#   'stand',
#   'voice'],
#  ['reject',
#   'laws',
#   'misguided',
#   'false',
#   'prophets',
#   'imprison',
#   'nations',
#   'fueling',
#   'self',
#   'annihilation'],
#  ['national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'change'],
#  ['annihilation',
#   'jeb',
#   'christie',
#   'kasich',
#   'less',
#   'hours',
#   'away',
#   'please',
#   'god',
#   'allow',
#   'least',
#   'full',
#   'day'],
#  ['barbitwins',
#   'need',
#   'die',
#   'please',
#   'sign',
#   'petition',
#   'take',
#   'stand',
#   'voice'],
#  ['whippenz',
#   'need',
#   'help',
#   'horses',
#   'dieplease',
#   'sign',
#   'petitiontake',
#   'stand',
#   'voice'],
#  ['hey',
#   'az',
#   'sign',
#   'petition',
#   'save',
#   'wildhorses',
#   'tantonationalforest',
#   'rollingstones',
#   'order'],
#  ['stop', 'annihilation', 'salt', 'river', 'wild', 'horses', 'change'],
#  ['sonofbaldwin',
#   'current',
#   'nova',
#   'bookslast',
#   'checkedhe',
#   'tied',
#   'books',
#   'rider',
#   'died',
#   'annihilation'],
#  ['national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'change'],
#  ['please', 'sign', 'save', 'saltriverwildhorses'],
#  ['thanks',
#   'count',
#   'dante',
#   'join',
#   'following',
#   'annihilation',
#   'zone',
#   'johnny'],
#  ['world',
#   'annihilation',
#   'vs',
#   'self',
#   'transformation',
#   'aliens',
#   'attack',
#   'exterminate',
#   'humans'],
#  ['national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'change'],
#  ['national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'change'],
#  ['gon', 'na', 'fight', 'taylor', 'soon'],
#  ['ohh',
#   'fukurodani',
#   'survive',
#   'apocalypse',
#   'bokuto',
#   'feels',
#   'horrible',
#   'poor',
#   'boy',
#   'ppor',
#   'child'],
#  ['another', 'jocelyn', 'birthday', 'apocalypse'],
#  ['stephenscifi',
#   'adaptation',
#   'watch',
#   'charlie',
#   'humans',
#   'apocalypse',
#   'optioned',
#   'film',
#   'sciencefiction'],
#  ['apocalypse', 'please'],
#  ['another',
#   'hour',
#   'august',
#   'red',
#   'rover',
#   'zombie',
#   'apocalypse',
#   'internetradio',
#   'collegeradi'],
#  ['honeybunzgem', 'primalkitchen', 'feel', 'stages', 'apocalypse'],
#  ['kinda',
#   'hot',
#   'played',
#   'radio',
#   'today',
#   'next',
#   'disease',
#   'apocalypse',
#   'started',
#   'everyone',
#   'careful'],
#  ['apocalypse', 'lol', 'gf'],
#  ['know', 'question', 'interpretation', 'sign', 'apocalypse', 'called'],
#  ['julie', 'r', 'apocalypse', 'version', 'romeo', 'juliet', 'warmbodies'],
#  ['apocalypse', 'upon'],
#  ['fittscott',
#   'night',
#   'lucky',
#   'block',
#   'mod',
#   'bob',
#   'apocalypse',
#   'wither',
#   'mod',
#   'showcase',
#   'popularmmos',
#   'vi'],
#  ['begins', 'day', 'snow', 'apocalypse'],
#  ['ourmothermary',
#   'short',
#   'reading',
#   'apocalypse',
#   'spirit',
#   'angel',
#   'took',
#   'top',
#   'enormous',
#   'high',
#   'mountain'],
#  ['candylit',
#   'imagine',
#   'sarumi',
#   'zombie',
#   'apocalypse',
#   'fighting',
#   'back',
#   'back',
#   'heart',
#   'heart',
#   'conversations'],
#  ['liked',
#   'youtube',
#   'minecraft',
#   'night',
#   'lucky',
#   'block',
#   'mod',
#   'bob',
#   'apocalypse',
#   'wither',
#   'mo'],
#  ['planet', 'lone', 'audience', 'apocalypse'],
#  ['dad',
#   'bought',
#   'dvd',
#   'looks',
#   'science',
#   'doc',
#   'front',
#   'read',
#   'back',
#   'actually',
#   'impending',
#   'biblical',
#   'apocalypse'],
#  ['alexandrapullin', 'indeed', 'apocalypse', 'comes', 'week', 'know'],
#  ['go',
#   'look',
#   'grizzly',
#   'peak',
#   'right',
#   'looks',
#   'beginning',
#   'dystopian',
#   'apocalypse',
#   'movie'],
#  ['niece', 'asked', 'would', 'scared', 'apocalypse'],
#  ['storm', 'cairo', 'latest', 'apocalypse', 'set', 'photo', 'yahootv'],
#  ['night',
#   'lucky',
#   'block',
#   'mod',
#   'bob',
#   'apocalypse',
#   'wither',
#   'mod',
#   'showcase',
#   'popularmmos',
#   'youtube'],
#  ['shot',
#   'heart',
#   'xv',
#   'going',
#   'totally',
#   'give',
#   'love',
#   'bad',
#   'name',
#   'heart',
#   'pierc'],
#  ['geekapocalypse', 'gmt', 'hesse', 'plays', 'dark', 'souls', 'day', 'etcpb'],
#  ['know', 'go', 'zombies', 'take'],
#  ['latest',
#   'bryansinger',
#   'reveals',
#   'storm',
#   'queen',
#   'apocalypse',
#   'rupaul',
#   'alexshipppp'],
#  ['shadow', 'boxing', 'apocalypse'],
#  ['short',
#   'reading',
#   'apocalypse',
#   'spirit',
#   'angel',
#   'took',
#   'top',
#   'enormous',
#   'high',
#   'mountain'],
#  ['enjoyed',
#   'attack',
#   'titan',
#   'every',
#   'time',
#   'see',
#   'posters',
#   'reminded',
#   'freshly',
#   'clean',
#   'coiffed',
#   'everyone',
#   'apocalypse'],
#  ['liked',
#   'youtube',
#   'minecraft',
#   'night',
#   'lucky',
#   'block',
#   'mod',
#   'bob',
#   'apocalypse',
#   'wither',
#   'mod',
#   'showcase'],
#  ['pbban', 'avysss', 'armageddon', 'kill', 'flags', 'fast', 'xp', 'reason'],
#  ['pbban', 'armageddon', 'kill', 'flags', 'fast', 'xp', 'reason'],
#  ['official',
#   'vid',
#   'doublecups',
#   'gtgt',
#   'gtgt',
#   'trubgme',
#   'prod',
#   'thisizbwright',
#   'gtgt',
#   'armageddon'],
#  ['ouvindo', 'peace', 'love', 'armageddon'],
#  ['best', 'movie', 'ever', 'seen', 'armageddon'],
#  ['bed', 'time', 'wake', 'unless', 'revolution', 'armageddon', 'start'],
#  ['red', 'faction', 'armageddon', 'microsoft', 'xbox', 'full', 'read', 'ebay'],
#  ['katiekatcubs',
#   'already',
#   'know',
#   'shit',
#   'goes',
#   'world',
#   'series',
#   'armageddon'],
#  ['love',
#   'truelove',
#   'romance',
#   'lith',
#   'voodoo',
#   'seduction',
#   'astrology',
#   'r',
#   'lotz',
#   'apocalypse',
#   'armageddon'],
#  ['im',
#   'gon',
#   'na',
#   'beat',
#   'armageddon',
#   'hsu',
#   'hao',
#   'got',
#   'flawless',
#   'first',
#   'try'],
#  ['enews',
#   'ben',
#   'afflecki',
#   'know',
#   'wifekids',
#   'girls',
#   'help',
#   'loved',
#   'since',
#   'armageddon',
#   'eonlinechat'],
#  ['would',
#   'long',
#   'coat',
#   'hand',
#   'would',
#   'worn',
#   'certainty',
#   'armageddon',
#   'bears',
#   'sense',
#   'occasion'],
#  ['phone',
#   'spying',
#   'hidden',
#   'back',
#   'door',
#   'nsa',
#   'data',
#   'mining',
#   'software',
#   'financial',
#   'armageddon',
#   'blog'],
#  ['pbban', 'armageddon', 'kill', 'flags', 'fast', 'xp', 'reason'],
#  ['rcoach',
#   'love',
#   'truelove',
#   'romance',
#   'lith',
#   'voodoo',
#   'seduction',
#   'astrology',
#   'r',
#   'lotz',
#   'apocalypse',
#   'armageddon'],
#  ['pbban',
#   'fighterdena',
#   'armageddon',
#   'kill',
#   'flags',
#   'fast',
#   'xp',
#   'reason'],
#  ['photo',
#   'sketch',
#   'based',
#   'taste',
#   'armageddon',
#   'episode',
#   'startrek',
#   'tos'],
#  ['armageddon'],
#  ['aberdeenfc',
#   'aberdeenfanpage',
#   'good',
#   'luck',
#   'tomorrow',
#   'night',
#   'coefficient',
#   'points',
#   'plz',
#   'armageddon'],
#  ['armageddon'],
#  ['rohnertparkdps',
#   'another',
#   'history',
#   'books',
#   'thank',
#   'justice',
#   'department',
#   'way',
#   'paid',
#   'income',
#   'tax'],
#  ['vladimir',
#   'putin',
#   'issues',
#   'major',
#   'warning',
#   'late',
#   'escape',
#   'armageddon'],
#  ['gods', 'kingdom', 'heavenly', 'govt', 'rule', 'earth', 'armageddon'],
#  ['l',
#   'b',
#   'entertainment',
#   'lot',
#   'brucewillis',
#   'movies',
#   'dvd',
#   'die',
#   'hard',
#   'monkeys',
#   'armageddon',
#   'sixth',
#   'ebay',
#   'auction'],
#  ['lets', 'talk', 'goof', 'guild', 'saunders', 'come', 'right', 'stage'],
#  ['karnythia',
#   'niece',
#   'gaining',
#   'ability',
#   'stand',
#   'getting',
#   'prepared',
#   'toddler',
#   'apocalypse',
#   'armageddon'],
#  ['check',
#   'preppers',
#   'doomsday',
#   'must',
#   'library',
#   'collection',
#   'cd',
#   'shtf',
#   'preppertalk',
#   'survival',
#   'prepper',
#   'ebay'],
#  ['erker',
#   'eep',
#   'thought',
#   'yesterday',
#   'saw',
#   'hella',
#   'scary',
#   'hail',
#   'armageddon'],
#  ['ahamedis',
#   'think',
#   'messiah',
#   'already',
#   'come',
#   'years',
#   'ago',
#   'armageddon',
#   'dajaal',
#   'gog',
#   'magog'],
#  ['sadly', 'windows', 'reveals', 'microsofts', 'ethics', 'armageddon'],
#  ['armageddon', 'averted', 'el', 'patron', 'ultimalucha'],
#  ['samihonkonen',
#   'time',
#   'hours',
#   'latest',
#   'series',
#   'blueprint',
#   'armageddon',
#   'extremely',
#   'impressive'],
#  ['european', 'fitba', 'till', 'christmas', 'armageddon'],
#  ['christians',
#   'united',
#   'israel',
#   'cufi',
#   'jews',
#   'convert',
#   'soon',
#   'die',
#   'armageddon'],
#  ['official',
#   'vid',
#   'gt',
#   'doublecups',
#   'gtgt',
#   'gtgt',
#   'trubgme',
#   'prod',
#   'thisizbwright',
#   'gtgt',
#   'armageddon'],
#  ['tomorrow', 'day', 'start', 'armageddon', 'preseasonworkouts'],
#  ['lee',
#   'comedy',
#   'leejasper',
#   'working',
#   'class',
#   'tories',
#   'prepare',
#   'armageddon',
#   'interestraterise'],
#  ['charts',
#   'prove',
#   'financial',
#   'crisis',
#   'part',
#   'begun',
#   'financial',
#   'armageddon',
#   'economic',
#   'collapse',
#   'blog',
#   'tracks',
#   'tren'],
#  ['paul',
#   'craig',
#   'roberts',
#   'vladimir',
#   'putin',
#   'issues',
#   'major',
#   'warning',
#   'late',
#   'escape',
#   'brics',
#   'roberts',
#   'russia'],
#  ['rohnertparkdps',
#   'stage',
#   'right',
#   'lights',
#   'funny',
#   'goofballs',
#   'staff',
#   'pd'],
#  ['official',
#   'vid',
#   'thereal',
#   'gtgtgt',
#   'gtgtgt',
#   'trubgme',
#   'gtgtgt',
#   'armageddon',
#   'comin',
#   'soon'],
#  ['well',
#   'done',
#   'celtic',
#   'fingers',
#   'crossed',
#   'aberdeen',
#   'tomorrow',
#   'night',
#   'armageddon',
#   'eh'],
#  ['beyonce', 'pick', 'fan', 'army', 'beyhive'],
#  ['direction', 'pick', 'fan', 'army', 'directioners'],
#  ['seconds', 'summer', 'pick', 'fan', 'army'],
#  ['pick', 'fan', 'army', 'beyhive'],
#  ['pick', 'fan', 'army', 'beyhive'],
#  ['direction', 'pick', 'fan', 'army', 'directioners'],
#  ['seeing',
#   'army',
#   'whitewalkers',
#   'first',
#   'thing',
#   'slightly',
#   'intrigued',
#   'got',
#   'far'],
#  ['build',
#   'kingdom',
#   'lead',
#   'army',
#   'victory',
#   'httpsyoutu',
#   'start',
#   'g',
#   'friend',
#   'code',
#   'lzktjnox'],
#  ['salvation',
#   'army',
#   'hosts',
#   'rally',
#   'reconnect',
#   'fathers',
#   'children',
#   'salvation',
#   'army',
#   'hosting',
#   'back',
#   'school',
#   'rally'],
#  ['vote',
#   'directioners',
#   'vs',
#   'queens',
#   'round',
#   'billboard',
#   'fanarmyfaceoff'],
#  ['build', 'army', 'dogs', 'leader', 'lion', 'dogs', 'fight', 'lion'],
#  ['show', 'hero', 'tv', 'review'],
#  ['direction', 'pick', 'fan', 'army', 'directioners'],
#  ['infantry',
#   'mens',
#   'lume',
#   'dial',
#   'army',
#   'analog',
#   'quartz',
#   'wrist',
#   'watch',
#   'sport',
#   'blue',
#   'nylon',
#   'fabric',
#   'full',
#   'rea'],
#  ['direction', 'pick', 'fan', 'army', 'directioners'],
#  ['victorinox', 'swiss', 'army', 'date', 'womens', 'rubber', 'mop', 'watch'],
#  ['indiakomuntorjawabdo', 'indian', 'army', 'ki'],
#  ['seconds', 'summer', 'pick', 'fan', 'army'],
#  ['beyonce', 'pick', 'fan', 'army', 'beyhive'],
#  ['direction', 'pick', 'fan', 'army', 'directioners'],
#  ['da',
#   'mtvsummerstar',
#   'videoveranomtv',
#   'mtvhottest',
#   'britney',
#   'spears',
#   'lana',
#   'del',
#   'rey'],
#  ['direction', 'pick', 'fan', 'army', 'directioners'],
#  ['stony',
#   'jackson',
#   'americas',
#   'last',
#   'hope',
#   'leads',
#   'army',
#   'felons',
#   'thus',
#   'army',
#   'rejects',
#   'army',
#   'satan'],
#  ['wwi',
#   'wwii',
#   'japanese',
#   'army',
#   'navy',
#   'military',
#   'japan',
#   'leather',
#   'watch',
#   'war',
#   'mido',
#   'full',
#   'read',
#   'ebay'],
#  ['beyonce', 'pick', 'fan', 'army', 'beyhive'],
#  ['pick', 'fan', 'army', 'beyhive'],
#  ['beyonce', 'pick', 'fan', 'army', 'beyhive'],
#  ['pick', 'fan', 'army', 'beyhive'],
#  ['potus',
#   'appoints',
#   'brig',
#   'gen',
#   'richard',
#   'g',
#   'kaiser',
#   'member',
#   'mississippi',
#   'river',
#   'commission',
#   'learn',
#   'mrc'],
#  ['ap',
#   'violent',
#   'country',
#   'army',
#   'involved',
#   'help',
#   'control',
#   'killings',
#   'bring',
#   'back',
#   'peace',
#   'poor'],
#  ['wwi',
#   'wwii',
#   'japanese',
#   'army',
#   'navy',
#   'military',
#   'japan',
#   'leather',
#   'watch',
#   'war',
#   'mido',
#   'full',
#   'read',
#   'ebay'],
#  ['wwi',
#   'wwii',
#   'japanese',
#   'army',
#   'navy',
#   'military',
#   'japan',
#   'leather',
#   'watch',
#   'war',
#   'mido',
#   'full',
#   'read',
#   'ebay'],
#  ['direction', 'pick', 'fan', 'army', 'directioners'],
#  ['direction', 'pick', 'fan', 'army', 'directioners'],
#  ['two', 'jewish', 'terrorists', 'charged', 'arson', 'ugly', 'truth'],
#  ['spokane',
#   'authorities',
#   'say',
#   'struggling',
#   'solve',
#   'arson',
#   'cases',
#   'todays',
#   'hamilton'],
#  ['thousands',
#   'attend',
#   'rally',
#   'organized',
#   'peace',
#   'protesting',
#   'arson',
#   'attack',
#   'took',
#   'life'],
#  ['add', 'familia', 'arson', 'squad'],
#  ['another',
#   'fake',
#   'hate',
#   'crime',
#   'lesbians',
#   'burn',
#   'house',
#   'else',
#   'new'],
#  ['los',
#   'angeles',
#   'times',
#   'arson',
#   'suspect',
#   'linked',
#   'fires',
#   'caught',
#   'northern',
#   'newsintweets'],
#  ['mourning',
#   'notices',
#   'stabbing',
#   'arson',
#   'victims',
#   'stir',
#   'politics',
#   'grief',
#   'israel'],
#  ['mourning',
#   'notices',
#   'stabbing',
#   'arson',
#   'victims',
#   'stir',
#   'politics',
#   'grief',
#   'israel'],
#  ['sound', 'arson'],
#  ['owner', 'gay', 'bar', 'admits', 'arson', 'scheme', 'lgbt'],
#  ['wait'],
#  ['arson', 'suspect', 'linked', 'fires', 'caught', 'northern', 'california'],
#  ['trial', 'date', 'set', 'man', 'charged', 'arson', 'burglary'],
#  ['death',
#   'palestinian',
#   'toddler',
#   'arson',
#   'attack',
#   'israel',
#   'cracks',
#   'jewish'],
#  ['palestinian', 'teen', 'killed', 'amid', 'protests', 'arson', 'attack'],
#  ['kisii',
#   'police',
#   'kisii',
#   'hunt',
#   'students',
#   'failed',
#   'arson',
#   'plot',
#   'police',
#   'kisii',
#   'hunt',
#   'students',
#   'countynews'],
#  ['mariah', 'getting', 'thick', 'shoulders', 'poor', 'girl'],
#  ['mourning',
#   'notices',
#   'stabbing',
#   'arson',
#   'victims',
#   'stir',
#   'politics',
#   'grief',
#   'israel',
#   'posters',
#   'shira',
#   'banki'],
#  ['relaxinpr',
#   'miprv',
#   'latimes',
#   'arson',
#   'suspect',
#   'linked',
#   'fires',
#   'caught',
#   'northern',
#   'california'],
#  ['jewish',
#   'leaders',
#   'prayed',
#   'hospital',
#   'palestinian',
#   'family',
#   'treated',
#   'arson',
#   'huffpostrelig'],
#  ['owner',
#   'gay',
#   'bar',
#   'admits',
#   'arson',
#   'scheme',
#   'theadvocatemag',
#   'lgbt'],
#  ['saynae', 'angel', 'arson'],
#  ['kisii',
#   'police',
#   'kisii',
#   'hunt',
#   'students',
#   'failed',
#   'arson',
#   'plot',
#   'police',
#   'kisii',
#   'hunt',
#   'students',
#   'countynews'],
#  ['mourning',
#   'notices',
#   'stabbing',
#   'arson',
#   'victims',
#   'stir',
#   'politics',
#   'grief',
#   'israel'],
#  ['owner',
#   'gay',
#   'bar',
#   'admits',
#   'arson',
#   'scheme',
#   'theadvocatemag',
#   'lgbt'],
#  ['owner', 'gay', 'bar', 'admits', 'arson', 'scheme', 'lgbt'],
#  ['mourning',
#   'notices',
#   'stabbing',
#   'arson',
#   'victims',
#   'stir',
#   'politics',
#   'grief',
#   'israel'],
#  ['owner', 'gay', 'bar', 'admits', 'arson', 'scheme', 'lgbt'],
#  ['arson',
#   'suspect',
#   'linked',
#   'fires',
#   'caught',
#   'northern',
#   'california',
#   'latimes'],
#  ['tennessee',
#   'lesbian',
#   'couple',
#   'faked',
#   'hate',
#   'crime',
#   'destroyed',
#   'home',
#   'arson',
#   'lesbian'],
#  ['arson',
#   'suspect',
#   'linked',
#   'fires',
#   'caught',
#   'northern',
#   'california',
#   'los',
#   'angeles',
#   'times'],
#  ['arson', 'suspect', 'linked', 'fires', 'caught', 'northern', 'california'],
#  ['cloudygoldrush', 'hate', 'white', 'mo'],
#  ['nowplaying', 'arsonist', 'mc', 'impressed', 'arsonistmusic'],
#  ['alleged', 'east', 'bay', 'serial', 'arsonist', 'arrested'],
#  ['safyuan',
#   'minor',
#   'citation',
#   'possesion',
#   'decriminalized',
#   'substance',
#   'im',
#   'facing',
#   'time'],
#  ['suspected', 'serial', 'arsonist', 'arrested', 'calif'],
#  ['arson', 'suspect', 'linked', 'fires', 'caught', 'northern', 'california'],
#  ['localarsonist', 'diamorfiend', 'legal', 'system', 'never', 'forgets'],
#  ['casperrmg', 'u', 'dick'],
#  ['bloorossington',
#   'arsonist',
#   'also',
#   'burned',
#   'mattress',
#   'northumberland',
#   'st',
#   'cbcto'],
#  ['wheres', 'arsonist'],
#  ['anything', 'nice', 'say', 'come', 'sit'],
#  ['vegetarian',
#   'vegan',
#   'shows',
#   'arsonist',
#   'torching',
#   'popular',
#   'bk',
#   'restaurant',
#   'strictly',
#   'vegetarian',
#   'govegan',
#   'uniteblue'],
#  ['arsonist',
#   'arrested',
#   'setting',
#   'many',
#   'fires',
#   'watch',
#   'tonights',
#   'headlines',
#   'nightbeat',
#   'veronicadlcruz'],
#  ['captures',
#   'man',
#   'removing',
#   'american',
#   'flag',
#   'long',
#   'beach',
#   'ca',
#   'home',
#   'burning',
#   'arsonist',
#   'sought'],
#  ['trick', 'think', 'nasty', 'things'],
#  ['spotlight',
#   'take',
#   'paradise',
#   'arsonist',
#   'mc',
#   'wniagospel',
#   'arsonistmusic'],
#  ['makes'],
#  ['town', 'salem', 'melted', 'ice', 'cube', 'bc', 'im', 'arsonist'],
#  ['arsonists',
#   'blamed',
#   'blaze',
#   'plastics',
#   'recycling',
#   'business',
#   'adelaide',
#   'reports'],
#  ['hotboy', 'shit'],
#  ['zodiac',
#   'girl',
#   'feat',
#   'trey',
#   'dupree',
#   'produced',
#   'sparkz',
#   'beatz',
#   'chuck',
#   'da',
#   'arsonist'],
#  ['localarsonist', 'lmfao'],
#  ['alleged', 'east', 'bay', 'serial', 'arsonist', 'arrested', 'sanfrancisco'],
#  ['doofus', 'diamorfiend', 'im', 'jokin', 'still', 'cant', 'moves'],
#  ['localarsonist', 'guess', 'u', 'say', 'shit', 'thinking'],
#  ['arsonist', 'sets', 'nyc', 'vegetarian', 'restaurant', 'police', 'newyork'],
#  ['liked', 'youtube', 'slimebeast', 'town', 'salem', 'win', 'arsonist'],
#  ['casperrmg', 'bestcomedyvine', 'whats', 'cracking', 'cuz'],
#  ['smoke',
#   'good',
#   'fuck',
#   'eat',
#   'drink',
#   'drive',
#   'nice',
#   'car',
#   'wear',
#   'green',
#   'mink'],
#  ['kill', 'got', 'court', 'day', 'earl'],
#  ['localarsonist', 'lmao', 'real', 'live', 'go'],
#  ['owner',
#   'gay',
#   'bar',
#   'admits',
#   'arson',
#   'scheme',
#   'frank',
#   'elliott',
#   'pleaded',
#   'guilty',
#   'hiring',
#   'arsonist'],
#  ['trusting',
#   'iran',
#   'stop',
#   'terrorism',
#   'inviting',
#   'arsonist',
#   'join',
#   'brigade',
#   'telegraph'],
#  ['big', 'top', 'burning', 'true', 'story', 'arsonist', 'missing', 'girl'],
#  ['stay',
#   'vigilent',
#   'civil',
#   'liberties',
#   'constant',
#   'attack',
#   'nativehuman',
#   'myreligion'],
#  ['credit', 'pfannebeckers', 'inspiring', 'rediscover', 'fantabulous', 'tbt'],
#  ['nashville',
#   'theater',
#   'attack',
#   'gun',
#   'grabbers',
#   'demand',
#   'hatchet',
#   'control'],
#  ['breaking', 'terror', 'attack', 'police', 'post', 'udhampur'],
#  ['demi',
#   'stans',
#   'really',
#   'think',
#   'heart',
#   'attack',
#   'sold',
#   'million',
#   'copies'],
#  ['scares',
#   'new',
#   'versions',
#   'nuclear',
#   'attack',
#   'warnings',
#   'knowing',
#   'governments',
#   'still',
#   'prepare'],
#  ['isil',
#   'claims',
#   'suicide',
#   'bombing',
#   'saudi',
#   'mosque',
#   'killed',
#   'least'],
#  ['dattomm', 'funniest', 'part', 'twitter', 'feminists', 'try', 'attack'],
#  ['horrific', 'attack', 'wife', 'muslim', 'italy', 'liveleak', 'news'],
#  ['blasts',
#   'accused',
#   'yeda',
#   'yakub',
#   'dies',
#   'karachi',
#   'heart',
#   'attack',
#   'mumbai'],
#  ['etribune',
#   'drone',
#   'attack',
#   'kills',
#   'militants',
#   'north',
#   'waziristan',
#   'acebreakingnews'],
#  ['suspect', 'latest', 'theater', 'attack', 'psychological', 'issues'],
#  ['militants',
#   'attack',
#   'police',
#   'post',
#   'udhampur',
#   'spos',
#   'injured',
#   'livemint',
#   'allthenews'],
#  ['breaking',
#   'obama',
#   'officials',
#   'gave',
#   'muslim',
#   'terrorist',
#   'weapon',
#   'used',
#   'texas',
#   'attack'],
#  ['delhi',
#   'government',
#   'provide',
#   'free',
#   'treatment',
#   'acid',
#   'attack',
#   'victims',
#   'private',
#   'hospitals'],
#  ['new',
#   'post',
#   'darkreading',
#   'new',
#   'smb',
#   'relay',
#   'attack',
#   'steals',
#   'user',
#   'credentials',
#   'internet'],
#  ['israeli',
#   'forces',
#   'raid',
#   'home',
#   'alleged',
#   'car',
#   'attack',
#   'suspect',
#   'palestine'],
#  ['heart', 'attack', 'thought', 'goat', 'dead', 'worry', 'rocket', 'okay'],
#  ['gon', 'na', 'lie', 'kinda', 'ready', 'attack', 'senior', 'year'],
#  ['left',
#   'hand',
#   'side',
#   'diamond',
#   'graveyard',
#   'shift',
#   'attack',
#   'defend',
#   'right',
#   'handside',
#   'fucking',
#   'idiot'],
#  ['volleyball',
#   'attack',
#   'ii',
#   'volleyball',
#   'training',
#   'machine',
#   'sets',
#   'simulation'],
#  ['notleys',
#   'tactful',
#   'yet',
#   'direct',
#   'response',
#   'harpers',
#   'attack',
#   'albertas',
#   'govt',
#   'hell',
#   'yeah',
#   'premier',
#   'ableg',
#   'cdnpoli'],
#  ['police',
#   'assailant',
#   'latest',
#   'movie',
#   'theatre',
#   'attack',
#   'homeless',
#   'psychological',
#   'issues'],
#  ['thanks', 'damn', 'heart', 'attack'],
#  ['suspect', 'latest', 'theatre', 'attack', 'psychological', 'issues'],
#  ['india',
#   'shud',
#   'give',
#   'evidence',
#   'pakthey',
#   'share',
#   'terrorists',
#   'use',
#   'next',
#   'attackshare',
#   'oth',
#   'contries'],
#  ['illegal',
#   'alien',
#   'released',
#   'obamadhs',
#   'times',
#   'charged',
#   'rape',
#   'murder',
#   'santa',
#   'maria',
#   'ca',
#   'woman',
#   'prior',
#   'offenses'],
#  ['strongly',
#   'condemn',
#   'attack',
#   'ary',
#   'news',
#   'team',
#   'karachi',
#   'cowardly',
#   'act',
#   'simply',
#   'trying',
#   'job'],
#  ['nashville',
#   'theater',
#   'attack',
#   'gun',
#   'grabbers',
#   'demand',
#   'hatchet',
#   'control'],
#  ['fact',
#   'atomic',
#   'bombs',
#   'called',
#   'little',
#   'boy',
#   'fat',
#   'man',
#   'says',
#   'lot',
#   'mentality',
#   'went',
#   'attack'],
#  ['blazerfan',
#   'everyone',
#   'see',
#   'ignoranceshe',
#   'latinoand',
#   'ever',
#   'benothing',
#   'morebut',
#   'attack',
#   'dog',
#   'hate',
#   'group',
#   'gop'],
#  ['heart', 'disease', 'prevention', 'secondhand', 'smoke'],
#  ['org', 'tells', 'hit', 'cyber', 'attack'],
#  ['attack', 'titan', 'game', 'ps', 'vita', 'yay', 'wait'],
#  ['infowars',
#   'nashville',
#   'theater',
#   'attack',
#   'gun',
#   'grabbers',
#   'demand',
#   'hatchet',
#   'control',
#   'nwo'],
#  ['anxiety', 'attack'],
#  ['dog', 'attacked', 'food', 'pugprobs'],
#  ['cop',
#   'injured',
#   'gunfight',
#   'militants',
#   'attack',
#   'udhampur',
#   'police',
#   'post',
#   'suspected',
#   'militants',
#   'attacked',
#   'police',
#   'post'],
#  ['nickcocofree',
#   'juliedicaro',
#   'asked',
#   'feel',
#   'attacked',
#   'julie',
#   'asked',
#   'frail'],
#  ['messeymetoo', 'feel', 'attacked'],
#  ['feeling', 'attacked'],
#  ['black',
#   'men',
#   'make',
#   'way',
#   'white',
#   'men',
#   'black',
#   'men',
#   'getting',
#   'attacked'],
#  ['cant',
#   'believe',
#   'fucking',
#   'cis',
#   'female',
#   'going',
#   'somehow',
#   'claim',
#   'offended',
#   'transgendered',
#   'female',
#   'attacked',
#   'media'],
#  ['israeli',
#   'helicopters',
#   'attacked',
#   'civilians',
#   'gaza',
#   'completed',
#   'exercises',
#   'greece'],
#  ['christian',
#   'attacked',
#   'muslims',
#   'temple',
#   'mount',
#   'waving',
#   'israeli',
#   'flag',
#   'pamela',
#   'geller'],
#  ['christian',
#   'attacked',
#   'muslims',
#   'temple',
#   'mount',
#   'waving',
#   'israeli',
#   'flag',
#   'pamela',
#   'geller'],
#  ['christian',
#   'attacked',
#   'muslims',
#   'temple',
#   'mount',
#   'waving',
#   'israeli',
#   'flag',
#   'pamela',
#   'geller'],
#  ['pt',
#   'unit',
#   'attacked',
#   'responsible',
#   'targeting',
#   'muslim',
#   'scholars',
#   'imprisoning',
#   'youth'],
#  ['telnet', 'attacked'],
#  ['christian',
#   'attacked',
#   'muslims',
#   'temple',
#   'mount',
#   'waving',
#   'israeli',
#   'flag',
#   'pamela',
#   'geller'],
#  ['tbt', 'remember', 'time', 'patrick', 'kane', 'attacked', 'cab', 'driver'],
#  ['im', 'feeling', 'attacked'],
#  ['ik',
#   'troll',
#   'pol',
#   'rivals',
#   'never',
#   'literally',
#   'abused',
#   'attacked',
#   'families',
#   'literally',
#   'abuse',
#   'ik',
#   'loosers'],
#  ['christian',
#   'attacked',
#   'muslims',
#   'temple',
#   'mount',
#   'waving',
#   'israeli',
#   'flag',
#   'pamela',
#   'geller'],
#  ['christian',
#   'attacked',
#   'muslims',
#   'temple',
#   'mount',
#   'waving',
#   'israeli',
#   'flag',
#   'pamela',
#   'geller'],
#  ['nickcocofree',
#   'juliedicaro',
#   'worst',
#   'person',
#   'questioning',
#   'julie',
#   'attacked',
#   'guys',
#   'empathy'],
#  ['kelly',
#   'osbourne',
#   'attacked',
#   'racist',
#   'donald',
#   'trump',
#   'remark',
#   'latinos',
#   'view'],
#  ['eunicenjoki', 'aiii', 'needs', 'chill', 'answer', 'calmly', 'attacked'],
#  ['christian',
#   'attacked',
#   'muslims',
#   'temple',
#   'mount',
#   'waving',
#   'israeli',
#   'flag',
# ...
#  ['love', 'cotton', 'candy', 'blizzard'],
#  ['tcgreno', 'hard', 'reset', 'xbox'],
#  ['really', 'wan', 'na', 'brownie', 'batter', 'blizzard'],
#  ['call', 'little', 'bit', 'blizzard'],
#  ['market',
#   'news',
#   'activision',
#   'blizzard',
#   'cognizant',
#   'technology',
#   'first',
#   'solar'],
#  ['sean', 'end', 'career', 'sg', 'blizzard', 'vs', 'knockout'],
#  ['biggest', 'regret', 'hearthstone'],
#  ['someone', 'walk', 'dq', 'wan', 'na', 'butterfinger', 'blizzard', 'bad'],
#  ['horrible',
#   'moment',
#   'u',
#   'open',
#   'dryer',
#   'looks',
#   'snowy',
#   'blizzard',
#   'cuz',
#   'u',
#   'left',
#   'piece',
#   'paper',
#   'jeans',
#   'pocket'],
#  ['lonewolffur', 'bruh', 'dies'],
#  ['rip', 'blood'],
#  ['chiefcg', 'nah', 'young', 'blood', 'cook', 'gone', 'cut', 'haha'],
#  ['wall', 'invincible', 'history', 'blood', 'dance', 'floor'],
#  ['broke',
#   'nailreal',
#   'fake',
#   'morning',
#   'blood',
#   'ah',
#   'hurts',
#   'ideas',
#   'treat',
#   'help',
#   'pretty',
#   'please'],
#  ['stars',
#   'reviewers',
#   'dragon',
#   'blood',
#   'boxset',
#   'lindsay',
#   'buroker',
#   'kindle'],
#  ['blood',
#   'group',
#   'associated',
#   'gastric',
#   'carcinoma',
#   'says',
#   'text',
#   'bookanother',
#   'fragile',
#   'gene',
#   'body'],
#  ['friend', 'blood', 'beside', 'always', 'come', 'wounded'],
#  ['gone', 'blood'],
#  ['tattoo', 'u', 'allowed', 'donate', 'blood', 'receive', 'blood', 'well'],
#  ['dialyses', 'grandpa', 'oh', 'lord', 'blood', 'makes', 'light', 'headed'],
#  ['setzorah',
#   'dad',
#   'dont',
#   'claim',
#   'mean',
#   'right',
#   'look',
#   'eyes',
#   'blood',
#   'xbox',
#   'smh'],
#  ['omron',
#   'automatic',
#   'blood',
#   'pressure',
#   'monitor',
#   'standard',
#   'large',
#   'bp',
#   'cuffs'],
#  ['blood', 'pressure', 'roof', 'need', 'extra', 'shit'],
#  ['chamberedblood', 'yeah', 'speakingfromexperience'],
#  ['believe',
#   'mid',
#   'high',
#   'blood',
#   'pressure',
#   'life',
#   'stressful',
#   'decisionsondecisions'],
#  ['guys', 'imouto', 'actually', 'related', 'blood'],
#  ['bruh',
#   'white',
#   'buy',
#   'ugliest',
#   'shoes',
#   'super',
#   'tight',
#   'blood',
#   'going',
#   'feet'],
#  ['another',
#   'day',
#   'another',
#   'excellent',
#   'dangerousbeans',
#   'porridge',
#   'seriously',
#   'blood',
#   'orange',
#   'porridge',
#   'phenomenal'],
#  ['happy', 'birthday', 'young', 'blood'],
#  ['blood'],
#  ['kinda', 'shii', 'nasty', 'blood', 'pun', 'intended'],
#  ['hoe', 'blood'],
#  ['today',
#   'hastle',
#   'getting',
#   'drug',
#   'tested',
#   'blood',
#   'drown',
#   'tb',
#   'shot',
#   'document',
#   'filling'],
#  ['man',
#   'somebody',
#   'got',
#   'ta',
#   'stop',
#   'sbee',
#   'dude',
#   'fuckin',
#   'funny',
#   'blood'],
#  ['winds', 'take', 'gypsy', 'blood', 'time'],
#  ['loboparanoico', 'mad', 'men'],
#  ['private', 'thirsty', 'nightsad', 'blood', 'rockn', 'roll'],
#  ['rolandonabeats',
#   'ellie',
#   'goulding',
#   'blood',
#   'acesse',
#   'nosso',
#   'site',
#   'para',
#   'ouvir'],
#  ['olrules',
#   'welcome',
#   'read',
#   'free',
#   'chapter',
#   'new',
#   'book',
#   'encounters',
#   'jesus',
#   'full',
#   'hope'],
#  ['anthxvy', 'runs', 'blood'],
#  ['sethalphaeus',
#   'personal',
#   'favorites',
#   'include',
#   'paramore',
#   'muse',
#   'green',
#   'day',
#   'royal',
#   'blood'],
#  ['shed',
#   'innocent',
#   'blood',
#   'sons',
#   'daughters',
#   'land',
#   'polluted',
#   'psalms',
#   'help',
#   'stop',
#   'sin',
#   'abortion'],
#  ['se', 'pone', 'cantar', 'crying', 'lightning'],
#  ['wasnt', 'big', 'stab', 'deep', 'stab', 'theres', 'blood', 'everwhe'],
#  ['add',
#   'items',
#   'everyday',
#   'eating',
#   'habits',
#   'please',
#   'research',
#   'take',
#   'blood'],
#  ['looooooooooool', 'bloody', 'hell'],
#  ['infected', 'bloody', 'ear', 'piercings', 'always', 'fun'],
#  ['aggressif', 'bloody', 'aggressive'],
#  ['entered',
#   'win',
#   'entire',
#   'set',
#   'butterlondon',
#   'lip',
#   'crayons',
#   'go',
#   'enter',
#   'bbloggers'],
#  ['slsandpet',
#   'hey',
#   'sally',
#   'sorry',
#   'emailed',
#   'awol',
#   'bloody',
#   'work',
#   'argh',
#   'resigninshame'],
#  ['listening', 'bloody', 'jay'],
#  ['lauradeholanda', 'forrest', 'version', 'bloody', 'awful', 'well', 'xxx'],
#  ['nightmare', 'elm', 'street', 'getting', 'remade'],
#  ['bloody',
#   'wait',
#   'sony',
#   'sets',
#   'date',
#   'stephen',
#   'kings',
#   'dark',
#   'tower',
#   'stephenking',
#   'thedarktower',
#   'bdisgusting'],
#  ['got', 'ta', 'try', 'let', 'go', 'many', 'bloody', 'things', 'smh'],
#  ['tradcatknight',
#   'russia',
#   'may',
#   'played',
#   'reason',
#   'link',
#   'bs',
#   'okanowa',
#   'bloody',
#   'mainline',
#   'invasion',
#   'looked',
#   'bloody'],
#  ['bloody', 'insomnia', 'grrrr', 'insomnia'],
#  ['zhenghxn',
#   'tried',
#   'eyes',
#   'akame',
#   'ga',
#   'kill',
#   'tokyo',
#   'ghoul',
#   'damn',
#   'bloody',
#   'dont',
#   'dare',
#   'watch'],
#  ['fantosex', 'suck', 'bloody', 'getting', 'means', 'amends'],
#  ['call',
#   'weekends',
#   'call',
#   'bloody',
#   'mary',
#   'times',
#   'summers',
#   'full',
#   'new'],
#  ['bloody',
#   'hell',
#   'day',
#   'even',
#   'really',
#   'done',
#   'anything',
#   'tired',
#   'everything',
#   'thought',
#   'vaca',
#   'would',
#   'help',
#   'much'],
#  ['damn', 'bloody', 'hot'],
#  ['mrtophypup', 'bloody', 'sexy', 'drools'],
#  ['know',
#   'say',
#   'side',
#   'effects',
#   'low',
#   'really',
#   'fast',
#   'son',
#   'product',
#   'acne',
#   'cream',
#   'side',
#   'effects',
#   'bloody',
#   'diarrhea'],
#  ['ronda',
#   'rousey',
#   'would',
#   'close',
#   'making',
#   'floyd',
#   'mayweathers',
#   'money',
#   'fights',
#   'bloody',
#   'elbow',
#   'boxing'],
#  ['awful', 'painting', 'agree', 'landscape', 'bloody', 'oils', 'paints'],
#  ['need',
#   'life',
#   'sin',
#   'girlfriend',
#   'ride',
#   'till',
#   'bloody',
#   'end',
#   'girlfriend'],
#  ['itsmegss', 'think', 'well', 'bloody', 'barking'],
#  ['eh',
#   'hello',
#   'cover',
#   'bloody',
#   'thighs',
#   'bloody',
#   'cleav',
#   'eh',
#   'hello',
#   'since',
#   'expose',
#   'cleavage'],
#  ['johnjcampbell', 'mega', 'bloody', 'marvellous'],
#  ['bloody', 'mary', 'sink', 'beet', 'juice'],
#  ['melrises',
#   'wwwbigbaldhead',
#   'jessienojoke',
#   'monty',
#   'python',
#   'date',
#   'bloody',
#   'far',
#   'wants',
#   'go'],
#  ['meet', 'bloody'],
#  ['friday', 'supposed', 'happy', 'day', 'bloody', 'friday', 'hah', 'zzzz'],
#  ['chxrmingprince',
#   'jonesluna',
#   'bloody',
#   'hope',
#   'said',
#   'folding',
#   'arms',
#   'sitting',
#   'back',
#   'chair'],
#  ['wait',
#   'tell',
#   'college',
#   'friend',
#   'reafs',
#   'bloody',
#   'mary',
#   'drama',
#   'cd'],
#  ['came',
#   'kill',
#   'indiansfor',
#   'fun',
#   'smirking',
#   'remorseless',
#   'pakistani',
#   'killer',
#   'shows',
#   'boasting'],
#  ['watched', 'episode', 'bloody', 'monday', 'bloodymonday', 'tvshowtime'],
#  ['marlon',
#   'williams',
#   'gt',
#   'elvis',
#   'presley',
#   'gt',
#   'marlon',
#   'williams',
#   'gt',
#   'steel',
#   'panther',
#   'shuffle',
#   'mode',
#   'bloody',
#   'legend'],
#  ['black',
#   'friday',
#   'turns',
#   'bloody',
#   'would',
#   'rather',
#   'shopping',
#   'mystery'],
#  ['ezralevant',
#   'someone',
#   'told',
#   'soccer',
#   'moms',
#   'getting',
#   'pic',
#   'blown',
#   'put',
#   'daughters',
#   'bedroom',
#   'walls'],
#  ['papcrdoll',
#   'mentions',
#   'blown',
#   'choice',
#   'deactivate',
#   'leave',
#   'good',
#   'respect',
#   'choices'],
#  ['manutd',
#   'emilymcfcheslop',
#   'wow',
#   'wow',
#   'club',
#   'blown',
#   'money',
#   'fucked',
#   'player',
#   'would',
#   'pilloried'],
#  ['damn', 'greinke', 'got', 'blown', 'first', 'inning'],
#  ['woke', 'blown', 'lol'],
#  ['aunt', 'marge', 'blown', 'eheks'],
#  ['troylercraft',
#   'yeah',
#   'woh',
#   'bc',
#   'already',
#   'many',
#   'spammers',
#   'twitter',
#   'probably',
#   'blown',
#   'every',
#   'second'],
#  ['white',
#   'family',
#   'supposedly',
#   'representing',
#   'americas',
#   'great',
#   'values',
#   'gets',
#   'blown',
#   'horrible',
#   'cgi',
#   'nuclear',
#   'strike',
#   'lmfaoooo'],
#  ['man', 'machinegunkelly', 'blown', 'still', 'underground'],
#  ['mentions', 'blown', 'wtf'],
#  ['thisdayinhistory',
#   'confederate',
#   'ship',
#   'blown',
#   'crew',
#   'read',
#   'history'],
#  ['moment',
#   'ur',
#   'win',
#   'mini',
#   'uhc',
#   'blown',
#   'creeper',
#   'kicked',
#   'flying',
#   'salty',
#   'rn'],
#  ['libraryeliza', 'bump', 'approval', 'probably', 'blown', 'musicadvisory'],
#  ['truckload',
#   'soldiers',
#   'blown',
#   'nobody',
#   'panics',
#   'little',
#   'lion',
#   'dies',
#   'everyone',
#   'loses',
#   'mind'],
#  ['hey',
#   'look',
#   'kashs',
#   'foundation',
#   'live',
#   'today',
#   'got',
#   'blown',
#   'magazines',
#   'website',
#   'todd',
#   'blake'],
#  ['got', 'last', 'month', 'went', 'ee', 'shop', 'glad', 'blown', 'yet'],
#  ['first', 'time', 'tweet', 'blown', 'almost', 'half', 'day', 'later'],
#  ['blown', 'away', 'extension', 'nothing', 'weve', 'seen', 'many', 'options'],
#  ['theboyofmasks',
#   'thanks',
#   'letting',
#   'stay',
#   'since',
#   'manor',
#   'blown',
#   'anyways',
#   'buddy'],
#  ['loner',
#   'diaries',
#   'patterns',
#   'sand',
#   'may',
#   'blown',
#   'away',
#   'photos',
#   'twos',
#   'choked',
#   'flames'],
#  ['even',
#   'though',
#   'bsg',
#   'sufficiently',
#   'hyped',
#   'years',
#   'somehow',
#   'delayed',
#   'watching',
#   'utterly',
#   'utterly',
#   'blown',
#   'away'],
#  ['vanessas',
#   'game',
#   'officially',
#   'blown',
#   'ladies',
#   'gentlementhe',
#   'real',
#   'show',
#   'begin'],
#  ['guaranteed',
#   'bitten',
#   'mutant',
#   'mosquito',
#   'ankle',
#   'blown',
#   'little',
#   'cunts'],
#  ['things',
#   'pick',
#   'tozlet',
#   'seat',
#   'butt',
#   'leprosy',
#   'jerkface',
#   'syndrome',
#   'lateral',
#   'lisp',
#   'toilet',
#   'rickets'],
#  ['kalinandmyles',
#   'kalinwhite',
#   'ig',
#   'blown',
#   'hackers',
#   'need',
#   'stop',
#   'givebackkalinwhiteaccount'],
#  ['lukewinkie',
#   'whoever',
#   'directing',
#   'videos',
#   'needs',
#   'grab',
#   'nicki',
#   'minaj',
#   'someone',
#   'recognition',
#   'minds',
#   'blown'],
#  ['princessduck',
#   'last',
#   'week',
#   'wanted',
#   'sense',
#   'blown',
#   'far',
#   'good',
#   'james',
#   'could',
#   'win',
#   'huge',
#   'target',
#   'gone',
#   'soon'],
#  ['orbette', 'blown', 'amirite'],
#  ['dogs', 'blown', 'kennel', 'bloody', 'yorkshire', 'terrorist'],
#  ['turn', 'blown'],
#  ['hopefulbatgirl',
#   'went',
#   'beaten',
#   'blown',
#   'next',
#   'thing',
#   'know',
#   'ra',
#   'al',
#   'ghul',
#   'brought',
#   'back',
#   'life',
#   'escaped'],
#  ['thebriankrause',
#   'leos',
#   'ass',
#   'got',
#   'metaphorically',
#   'blown',
#   'piperwearsthepants',
#   'charmed'],
#  ['anarchicteapot',
#   'boironusa',
#   'glononium',
#   'also',
#   'helps',
#   'blown',
#   'bashing',
#   'bottle',
#   'nitroglycerin',
#   'book'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'women',
#   'cross',
#   'body',
#   'bag',
#   'faux',
#   'leather',
#   'fashion',
#   'purse',
#   'full'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'women',
#   'cross',
#   'body',
#   'bag',
#   'faux',
#   'leather',
#   'fashion',
#   'purse',
#   'full'],
#  ['son',
#   'daughter',
#   'would',
#   'see',
#   'going',
#   'war',
#   'iran',
#   'come',
#   'back',
#   'body',
#   'bag',
#   'let',
#   'republicans',
#   'know'],
#  ['questergirl',
#   'ditto',
#   'way',
#   'feel',
#   'drank',
#   'vodka',
#   'ice',
#   'would',
#   'body',
#   'bag'],
#  ['handbags',
#   'genuine',
#   'mulberry',
#   'antony',
#   'cross',
#   'body',
#   'messenger',
#   'bag',
#   'dark',
#   'oak',
#   'soft',
#   'buffalo',
#   'leather',
#   'date',
#   'w'],
#  ['louis',
#   'vuitton',
#   'monogram',
#   'sophie',
#   'limited',
#   'edition',
#   'clutch',
#   'cross',
#   'body',
#   'bag',
#   'full',
#   'read',
#   'ebay'],
#  ['louis',
#   'vuitton',
#   'monogram',
#   'sophie',
#   'limited',
#   'edition',
#   'clutch',
#   'cross',
#   'body',
#   'bag',
#   'full',
#   'read',
#   'ebay'],
#  ['louis',
#   'vuitton',
#   'cultsierre',
#   'monogram',
#   'shoulder',
#   'bag',
#   'cross',
#   'body',
#   'bag'],
#  ['check',
#   'ameribag',
#   'healthy',
#   'back',
#   'bag',
#   'shoulder',
#   'cross',
#   'body',
#   'backpack',
#   'khaki',
#   'tan',
#   'beige',
#   'nylon',
#   'ebay'],
#  ['photo',
#   'bath',
#   'body',
#   'works',
#   'cosmetic',
#   'bag',
#   'periwinkle',
#   'blue',
#   'copper',
#   'piping',
#   'along',
#   'top',
#   'four',
#   'corners'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'women',
#   'cross',
#   'body',
#   'bag',
#   'faux',
#   'leather',
#   'fashion',
#   'purse',
#   'full'],
#  ['new',
#   'summer',
#   'long',
#   'thin',
#   'body',
#   'bag',
#   'hip',
#   'word',
#   'skirt',
#   'blue'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens',
#   'en'],
#  ['trjdavis',
#   'bruh',
#   'wan',
#   'na',
#   'fight',
#   'meet',
#   'cage',
#   'bro',
#   'better',
#   'find',
#   'dealing',
#   'end',
#   'body',
#   'bag'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens',
#   'full',
#   'read'],
#  ['auth',
#   'louis',
#   'vuitton',
#   'brown',
#   'saumur',
#   'cross',
#   'body',
#   'shoulder',
#   'bag',
#   'monogram',
#   'full',
#   'read'],
#  ['check',
#   'vintage',
#   'longaberger',
#   'floral',
#   'fabric',
#   'shoulder',
#   'cross',
#   'body',
#   'bag',
#   'brown',
#   'leather',
#   'strap',
#   'ebay'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens'],
#  ['new',
#   'summer',
#   'long',
#   'thin',
#   'body',
#   'bag',
#   'hip',
#   'word',
#   'skirt',
#   'blue'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens',
#   'en'],
#  ['louis',
#   'vuitton',
#   'monogram',
#   'sophie',
#   'limited',
#   'edition',
#   'clutch',
#   'cross',
#   'body',
#   'bag',
#   'full',
#   'read',
#   'ebay'],
#  ['new',
#   'women',
#   'handbag',
#   'faux',
#   'leather',
#   'ladies',
#   'shoulder',
#   'tote',
#   'cross',
#   'body',
#   'bag',
#   'large',
#   'satchel',
#   'full'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens'],
#  ['day', 'heart', 'gone', 'zipped', 'body', 'bag'],
#  ['handbag',
#   'fashion',
#   'style',
#   'authentic',
#   'louis',
#   'vuitton',
#   'pochette',
#   'bosphore',
#   'shoulder',
#   'cross',
#   'body',
#   'bag'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens'],
#  ['handbag',
#   'fashion',
#   'style',
#   'vintage',
#   'coach',
#   'purse',
#   'camera',
#   'bag',
#   'cross',
#   'body',
#   'bids'],
#  ['genuine',
#   'leather',
#   'man',
#   'bag',
#   'messenger',
#   'fit',
#   'ipad',
#   'mini',
#   'tablet',
#   'case',
#   'cross',
#   'body',
#   'air',
#   'jp',
#   'full',
#   'rea'],
#  ['louis',
#   'vuitton',
#   'monogram',
#   'sophie',
#   'limited',
#   'edition',
#   'clutch',
#   'cross',
#   'body',
#   'bag',
#   'full',
#   'read',
#   'ebay'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens'],
#  ['nuu', 'fam', 'fwt', 'leave', 'body', 'bag'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens',
#   'full',
#   'read'],
#  ['deliciousvomit',
#   'saying',
#   'lucky',
#   'go',
#   'home',
#   'families',
#   'put',
#   'body',
#   'bag'],
#  ['mattbez', 'oh', 'bagging', 'body', 'bangin', 'saying', 'going', 'rose'],
#  ['ohmyloz', 'rondarousey', 'bagging', 'body', 'smoking', 'hot'],
#  ['drake', 'really', 'body', 'bagging', 'meek'],
#  ['fuckyeahcarey',
#   'bornverified',
#   'drake',
#   'killing',
#   'dude',
#   'tea',
#   'bagging',
#   'dead',
#   'body',
#   'point'],
#  ['meekmill',
#   'wreck',
#   'league',
#   'ball',
#   'drake',
#   'olympic',
#   'level',
#   'body',
#   'bagging',
#   'career',
#   'nothing',
#   'trollingtilmeekdiss'],
#  ['idgaf',
#   'tough',
#   'canada',
#   'north',
#   'philly',
#   'meek',
#   'acting',
#   'bitch',
#   'drake',
#   'body',
#   'bagging',
#   'ass',
#   'tracks'],
#  ['yankees', 'body', 'bagging', 'mfs'],
#  ['broseidonrex',
#   'dapurplesharpie',
#   'skimmed',
#   'twitter',
#   'missed',
#   'body',
#   'bagging'],
#  ['g', 'body', 'bagging', 'lyrically'],
#  ['bomairinge', 'elutranscendent', 'straight', 'body', 'bagging'],
#  ['body', 'bagging', 'bitches'],
#  ['better',
#   'feeling',
#   'seeing',
#   'stage',
#   'day',
#   'ones',
#   'year',
#   'friendships',
#   'still',
#   'body',
#   'bagging',
#   'mics',
#   'together'],
#  ['mopheme',
#   'bigstar',
#   'johnson',
#   'problem',
#   'game',
#   'body',
#   'bagging',
#   'niggas',
#   'vuzuhustle'],
#  ['body', 'bagging', 'post', 'score'],
#  ['editaxohaze',
#   'let',
#   'bagging',
#   'bodys',
#   'begin',
#   'lol',
#   'cuffed',
#   'yet',
#   'bad'],
#  ...]

# %%
for i, word in enumerate(wv.vocab):
    if i == 10:
        break
    print(word)

# %%
## otra cosa

# %%
#separo por grupos
dfreal = df[df['target']==1]
dffalso = df[df['target']==0]

dfreal['words']
# Out:
# 0       [deeds, reason, earthquake, may, allah, forgive, us]
# 1       [forest, fire, near, la, ronge, sask, canada]
# 2       [residents, asked, shelter, place, notified, officers, evacuation, shelter, place, orders, expected]
# 3       [people, receive, wildfires, evacuation, orders, california]
# 4       [got, sent, photo, ruby, alaska, smoke, wildfires, pours, school]
#                                       ...
# 7608    [two, giant, cranes, holding, bridge, collapse, nearby, homes]
# 7609    [ariaahrary, thetawniest, control, wild, fires, california, even, northern, part, state, troubling]
# 7610    [m194, 5km, volcano, hawaii]
# 7611    [police, investigating, ebike, collided, car, little, portugal, ebike, rider, suffered, serious, nonlife, threatening, injuries]
# 7612    [latest, homes, razed, northern, california, wildfire, abc, news]
# Name: words, Length: 3271, dtype: object

# %%
lista = df['words'].tolist()
lista = sum(lista, [])
lista
# Out:
# ['deeds',
#  'reason',
#  'earthquake',
#  'may',
#  'allah',
#  'forgive',
#  'us',
#  'forest',
#  'fire',
#  'near',
#  'la',
#  'ronge',
#  'sask',
#  'canada',
#  'residents',
#  'asked',
#  'shelter',
#  'place',
#  'notified',
#  'officers',
#  'evacuation',
#  'shelter',
#  'place',
#  'orders',
#  'expected',
#  'people',
#  'receive',
#  'wildfires',
#  'evacuation',
#  'orders',
#  'california',
#  'got',
#  'sent',
#  'photo',
#  'ruby',
#  'alaska',
#  'smoke',
#  'wildfires',
#  'pours',
#  'school',
#  'rockyfire',
#  'update',
#  'california',
#  'hwy',
#  'closed',
#  'directions',
#  'due',
#  'lake',
#  'county',
#  'fire',
#  'cafire',
#  'wildfires',
#  'flood',
#  'disaster',
#  'heavy',
#  'rain',
#  'causes',
#  'flash',
#  'flooding',
#  'streets',
#  'manitou',
#  'colorado',
#  'springs',
#  'areas',
#  'top',
#  'hill',
#  'see',
#  'fire',
#  'woods',
#  'theres',
#  'emergency',
#  'evacuation',
#  'happening',
#  'building',
#  'across',
#  'street',
#  'afraid',
#  'tornado',
#  'coming',
#  'area',
#  'three',
#  'people',
#  'died',
#  'heat',
#  'wave',
#  'far',
#  'haha',
#  'south',
#  'tampa',
#  'getting',
#  'flooded',
#  'hah',
#  'wait',
#  'second',
#  'live',
#  'south',
#  'tampa',
#  'gonna',
#  'gonna',
#  'fvck',
#  'flooding',
#  'raining',
#  'flooding',
#  'florida',
#  'tampabay',
#  'tampa',
#  'days',
#  'ive',
#  'lost',
#  'count',
#  'flood',
#  'bago',
#  'myanmar',
#  'arrived',
#  'bago',
#  'damage',
#  'school',
#  'bus',
#  'multi',
#  'car',
#  'crash',
#  'breaking',
#  'whats',
#  'man',
#  'love',
#  'fruits',
#  'summer',
#  'lovely',
#  'car',
#  'fast',
#  'goooooooaaaaaal',
#  'ridiculous',
#  'london',
#  'cool',
#  'love',
#  'skiing',
#  'wonderful',
#  'day',
#  'looooool',
#  'wayi',
#  'cant',
#  'eat',
#  'shit',
#  'nyc',
#  'last',
#  'week',
#  'love',
#  'girlfriend',
#  'cooool',
#  'like',
#  'pasta',
#  'end',
#  'bbcmtd',
#  'wholesale',
#  'markets',
#  'ablaze',
#  'always',
#  'try',
#  'bring',
#  'heavy',
#  'metal',
#  'rt',
#  'africanbaze',
#  'breaking',
#  'newsnigeria',
#  'flag',
#  'set',
#  'ablaze',
#  'aba',
#  'crying',
#  'set',
#  'ablaze',
#  'plus',
#  'side',
#  'look',
#  'sky',
#  'last',
#  'night',
#  'ablaze',
#  'phdsquares',
#  'mufc',
#  'theyve',
#  'built',
#  'much',
#  'hype',
#  'around',
#  'new',
#  'acquisitions',
#  'doubt',
#  'set',
#  'epl',
#  'ablaze',
#  'season',
#  'inec',
#  'office',
#  'abia',
#  'set',
#  'ablaze',
#  'barbados',
#  'bridgetown',
#  'jamaica',
#  '\x89ûò',
#  'two',
#  'cars',
#  'set',
#  'ablaze',
#  'santa',
#  'cruz',
#  '\x89ûó',
#  'head',
#  'st',
#  'elizabeth',
#  'police',
#  'superintende',
#  'ablaze',
#  'lord',
#  'check',
#  'nsfw',
#  'outside',
#  'youre',
#  'ablaze',
#  'alive',
#  'youre',
#  'dead',
#  'inside',
#  'awesome',
#  'time',
#  'visiting',
#  'cfc',
#  'head',
#  'office',
#  'ancop',
#  'site',
#  'ablaze',
#  'thanks',
#  'tita',
#  'vida',
#  'taking',
#  'care',
#  'us',
#  'soooo',
#  'pumped',
#  'ablaze',
#  'southridgelife',
#  'wanted',
#  'set',
#  'chicago',
#  'ablaze',
#  'preaching',
#  'hotel',
#  'gained',
#  'followers',
#  'last',
#  'week',
#  'know',
#  'stats',
#  'grow',
#  'west',
#  'burned',
#  'thousands',
#  'wildfires',
#  'ablaze',
#  'california',
#  'alone',
#  'building',
#  'perfect',
#  'tracklist',
#  'life',
#  'leave',
#  'streets',
#  'ablaze',
#  'check',
#  'nsfw',
#  'first',
#  'night',
#  'retainers',
#  'quite',
#  'weird',
#  'better',
#  'used',
#  'wear',
#  'every',
#  'single',
#  'night',
#  'next',
#  'year',
#  'least',
#  'deputies',
#  'man',
#  'shot',
#  'brighton',
#  'home',
#  'set',
#  'ablaze',
#  'man',
#  'wife',
#  'six',
#  'years',
#  'jail',
#  'setting',
#  'ablaze',
#  'niece',
#  'santa',
#  'cruz',
#  '\x89ûó',
#  'head',
#  'st',
#  'elizabeth',
#  'police',
#  'superintendent',
#  'lanford',
#  'salmon',
#  'r',
#  'police',
#  'arsonist',
#  'deliberately',
#  'set',
#  'black',
#  'church',
#  'north',
#  'carolinaåêablaze',
#  'noches',
#  'elbestia',
#  'alexissanchez',
#  'happy',
#  'see',
#  'teammates',
#  'training',
#  'hard',
#  'goodnight',
#  'gunners',
#  'kurds',
#  'trampling',
#  'turkmen',
#  'flag',
#  'later',
#  'set',
#  'ablaze',
#  'others',
#  'vandalized',
#  'offices',
#  'turkmen',
#  'front',
#  'diyala',
#  'truck',
#  'ablaze',
#  'r21',
#  'voortrekker',
#  'ave',
#  'outside',
#  'tambo',
#  'intl',
#  'cargo',
#  'section',
#  'set',
#  'hearts',
#  'ablaze',
#  'every',
#  'city',
#  'gift',
#  'every',
#  'skyline',
#  'like',
#  'kiss',
#  'upon',
#  'lips',
#  '\x89û',
#  'sky',
#  'ablaze',
#  'tonight',
#  'los',
#  'angeles',
#  'expecting',
#  'ig',
#  'fb',
#  'filled',
#  'sunset',
#  'shots',
#  'know',
#  'peeps',
#  'west',
#  'burned',
#  'thousands',
#  'wildfires',
#  'ablaze',
#  'california',
#  'alone',
#  'climate',
#  'energy',
#  'revel',
#  'wmv',
#  'videos',
#  'means',
#  'mac',
#  'farewell',
#  'ablaze',
#  'wmv',
#  'en',
#  'route',
#  'dvd',
#  'gtxrwm',
#  'progressive',
#  'greetings',
#  'month',
#  'students',
#  'set',
#  'pens',
#  'ablaze',
#  'torch',
#  'publications',
#  'rene',
#  'ablaze',
#  'jacinta',
#  'secret',
#  '2k13',
#  'fallen',
#  'skies',
#  'edit',
#  'mar',
#  'navista7',
#  'steve',
#  'fires',
#  'something',
#  'else',
#  'california',
#  'tinderbox',
#  'clown',
#  'setting',
#  'hood',
#  'ablaze',
#  'news24680',
#  'nowplaying',
#  'rene',
#  'ablaze',
#  'ian',
#  'buff',
#  'magnitude',
#  'edm',
#  'nxwestmidlands',
#  'huge',
#  'fire',
#  'wholesale',
#  'markets',
#  'ablaze',
#  'ablaze',
#  'time',
#  'talk',
#  'know',
#  'make',
#  'due',
#  'work',
#  'cant',
#  'kids',
#  'cuz',
#  'got',
#  'bicycle',
#  'accident',
#  'split',
#  'testicles',
#  'impossible',
#  'kids',
#  'michael',
#  'father',
#  'accident',
#  'i24',
#  'w',
#  'nashvilletraffic',
#  'traffic',
#  'moving',
#  '8m',
#  'slower',
#  'usual',
#  'accident',
#  'center',
#  'lane',
#  'blocked',
#  'santaclara',
#  'us101',
#  'nb',
#  'great',
#  'america',
#  'pkwy',
#  'bayarea',
#  'traffic',
#  'personalinjury',
#  'accident',
#  'summer',
#  'read',
#  'advice',
#  'see',
#  'solicitor',
#  'help',
#  'otleyhour',
#  'stlouis',
#  'caraccidentlawyer',
#  'speeding',
#  'among',
#  'top',
#  'causes',
#  'teen',
#  'accidents',
#  'car',
#  'accident',
#  'tee\x89û',
#  'reported',
#  'motor',
#  'vehicle',
#  'accident',
#  'curry',
#  'herman',
#  'rd',
#  'near',
#  'stephenson',
#  'involving',
#  'overturned',
#  'vehicle',
#  'please',
#  'use',
#  'bigrigradio',
#  'live',
#  'accident',
#  'awareness',
#  'i77',
#  'mile',
#  'marker',
#  'south',
#  'mooresville',
#  'iredell',
#  'vehicle',
#  'accident',
#  'ramp',
#  'closed',
#  'pm',
#  'rt',
#  'sleepjunkies',
#  'sleeping',
#  'pills',
#  'double',
#  'risk',
#  'car',
#  'accident',
#  'accident',
#  'knew',
#  'gon',
#  'happen',
#  'traffic',
#  'accident',
#  'n',
#  'cabrillo',
#  'hwymagellan',
#  'av',
#  'mir',
#  'i77',
#  'mile',
#  'marker',
#  'south',
#  'mooresville',
#  'iredell',
#  'vehicle',
#  'accident',
#  'congestion',
#  'pm',
#  'pastor',
#  'scene',
#  'accidentwho',
#  'owner',
#  'range',
#  'rover',
#  'mom',
#  'didnt',
#  'home',
#  'fast',
#  'wished',
#  'mom',
#  'accident',
#  'truck',
#  'spilt',
#  'mayonnaise',
#  'horrible',
#  'car',
#  'accident',
#  'past',
#  'sunday',
#  'finally',
#  'able',
#  'around',
#  'thank',
#  'god',
#  'wait',
#  'see',
#  'pissed',
#  'donnie',
#  'tell',
#  'another',
#  'accident',
#  'truckcrash',
#  'overturns',
#  'fortworth',
#  'interstate',
#  'click',
#  'youve',
#  'crashgt',
#  'accident',
#  'ashville',
#  'us',
#  'sb',
#  'sr',
#  'traffic',
#  'carolina',
#  'accident',
#  'motorcyclist',
#  'dies',
#  'i540',
#  'crash',
#  'car',
#  'crossed',
#  'median',
#  'motorcycle',
#  'rider',
#  'traveling',
#  'fyi',
#  'cadfyi',
#  'accident',
#  'property',
#  'damagenhs999',
#  'piner',
#  'rdhorndale',
#  'dr',
#  'rt',
#  'naayf',
#  'first',
#  'accident',
#  'years',
#  'turning',
#  'onto',
#  'chandanee',
#  'magu',
#  'near',
#  'mma',
#  'taxi',
#  'rammed',
#  'halfway',
#  'turned',
#  'everyone',
#  'conf\x89û',
#  'accident',
#  'left',
#  'lane',
#  'blocked',
#  'manchester',
#  'rt',
#  'nb',
#  'eddy',
#  'rd',
#  'stop',
#  'traffic',
#  'back',
#  'nh3a',
#  'delay',
#  'mins',
#  'traffic',
#  'accident',
#  'property',
#  'damage',
#  'piner',
#  'rdhorndale',
#  'dr',
#  'accident',
#  'fyi',
#  'cadfyi',
#  'accident',
#  'property',
#  'damagewpd1600',
#  '17th',
#  'st',
#  'pm',
#  'traffic',
#  'accident',
#  'injury',
#  'willis',
#  'foreman',
#  'rd',
#  'aashiqui',
#  'actress',
#  'anu',
#  'aggarwal',
#  'nearfatal',
#  'accident',
#  'suffield',
#  'alberta',
#  'accident',
#  'mile',
#  'backup',
#  'i77',
#  'southaccident',
#  'blocking',
#  'right',
#  'lanes',
#  'exit',
#  'langtree',
#  'rdconsider',
#  'nc',
#  'nc',
#  'nc',
#  'alternate',
#  'accident',
#  'changed',
#  'life',
#  'help',
#  'determine',
#  'options',
#  'financially',
#  'support',
#  'life',
#  'care',
#  'plans',
#  'ongoing',
#  'treatment',
#  'breaking',
#  'deadly',
#  'motorcycle',
#  'car',
#  'accident',
#  'happened',
#  'hagerstown',
#  'today',
#  'ill',
#  'details',
#  'your4state',
#  'whag',
#  'flowri',
#  'marinading',
#  'accident',
#  'car',
#  'even',
#  'week',
#  'got',
#  'fucking',
#  'car',
#  'accident',
#  'mfs',
#  'cant',
#  'fucking',
#  'drive',
#  'norwaymfa',
#  'bahrain',
#  'police',
#  'previously',
#  'died',
#  'road',
#  'accident',
#  'killed',
#  'explosion',
#  'still',
#  'heard',
#  'church',
#  'leaders',
#  'kenya',
#  'coming',
#  'forward',
#  'comment',
#  'accident',
#  'issue',
#  'disciplinary',
#  'measuresarrestpastornganga',
#  'aftershockdelo',
#  'scuf',
#  'ps',
#  'live',
#  'game',
#  'cya',
#  'man',
#  'drive',
#  'effort',
#  'gets',
#  'painful',
#  'man',
#  'win',
#  'roger',
#  'bannister',
#  'icemoon',
#  'djicemoon',
#  'dubstep',
#  'trapmusic',
#  'dnb',
#  'edm',
#  'dance',
#  'ices\x89û',
#  'victory',
#  'bargain',
#  'basement',
#  'prices',
#  'dwight',
#  'david',
#  'eisenhower',
#  'icemoon',
#  'djicemoon',
#  'dubstep',
#  'trapmusic',
#  'dnb',
#  'edm',
#  'dance',
#  'ices\x89û',
#  'nobody',
#  'remembers',
#  'came',
#  'second',
#  'charles',
#  'schulz',
#  'aftershockdelo',
#  'speaking',
#  'someone',
#  'using',
#  'scuf',
#  'xb1',
#  'people',
#  'end',
#  'getting',
#  'ps',
#  'also',
#  'harder',
#  'conflict',
#  'glorious',
#  'triumph',
#  'thomas',
#  'paine',
#  'growingupspoiled',
#  'going',
#  'clay',
#  'pigeon',
#  'shooting',
#  'crying',
#  'aftershock',
#  'guess',
#  'actually',
#  'wants',
#  'free',
#  'aftershock',
#  'tc',
#  'aftershock',
#  'terrifying',
#  'best',
#  'roller',
#  'coaster',
#  'ive',
#  'ever',
#  'disclaimer',
#  'ive',
#  'aftershock',
#  'icemoon',
#  'djicemoon',
#  'dubstep',
#  'trapmusic',
#  'dnb',
#  'edm',
#  'dance',
#  'ices\x89û',
#  'icemoon',
#  'djicemoon',
#  'dubstep',
#  'trapmusic',
#  'dnb',
#  'edm',
#  'dance',
#  'ices\x89û',
#  'icemoon',
#  'djicemoon',
#  'dubstep',
#  'trapmusic',
#  'dnb',
#  'edm',
#  'dance',
#  'ices\x89û',
#  'kjfordays',
#  'seeing',
#  'issues',
#  'aftershock',
#  'icemoon',
#  'djicemoon',
#  'dubstep',
#  'trapmusic',
#  'dnb',
#  'edm',
#  'dance',
#  'ices\x89û',
#  'icemoon',
#  'djicemoon',
#  'dubstep',
#  'trapmusic',
#  'dnb',
#  'edm',
#  'dance',
#  'ices\x89û',
#  'wisdomwed',
#  'bonus',
#  'minute',
#  'daily',
#  'habits',
#  'could',
#  'really',
#  'improve',
#  'life',
#  'many',
#  'already',
#  'lifehacks',
#  'aftershock',
#  'protect',
#  'profit',
#  'next',
#  'global',
#  'financial',
#  'meltdown',
#  'david',
#  'wiedemer',
#  'http',
#  'moment',
#  'scary',
#  'roller',
#  'coaster',
#  'guy',
#  'behind',
#  'screaming',
#  'bloody',
#  'murder',
#  'silverwood',
#  'aftershock',
#  'aftershock',
#  '\x89ã¢',
#  'full\x89ã¢',
#  'streaming',
#  'youtube',
#  'gtgt',
#  'aftershock',
#  'protect',
#  'profit',
#  'next',
#  'global',
#  'financial',
#  'book',
#  'esquireattire',
#  'sometimes',
#  'face',
#  'difficulties',
#  'youre',
#  'something',
#  'wrong',
#  'youre',
#  'something',
#  'right',
#  'joel',
#  'osteen',
#  'thing',
#  'stands',
#  'dream',
#  'try',
#  'belief',
#  'actually',
#  'possible',
#  'joel',
#  'brown',
#  'praise',
#  'god',
#  'ministry',
#  'tells',
#  'like',
#  'wdyouth',
#  'biblestudy',
#  'remembering',
#  'going',
#  'die',
#  'best',
#  'way',
#  'know',
#  'avoid',
#  'trap',
#  'thinking',
#  'something',
#  'lose',
#  '\x89ûò',
#  'steve',
#  'jobs',
#  'tried',
#  'orange',
#  'aftershock',
#  'today',
#  'life',
#  'never',
#  'onfireanders',
#  'love',
#  'bb',
#  'aftershock',
#  'aftershock',
#  'back',
#  'school',
#  'kick',
#  'great',
#  'want',
#  'thank',
#  'everyone',
#  'making',
#  ...]

# %%
listaset = set(lista)
listaset
# Out:
# {'bore',
#  'listeria',
#  'cafe',
#  'platt',
#  'ampor',
#  'dublin',
#  'dismisses',
#  'saintrobinho86',
#  'gum',
#  'sneaks',
#  'paranormal',
#  'declared',
#  'ruins',
#  'shipwreck',
#  'hopped',
#  'preconditioning',
#  'fuckfacewineisdumbcom',
#  'prepared',
#  'cityamp3others',
#  'gregory',
#  'atomicbomb',
#  'contries',
#  'ep016',
#  'sweater',
#  'aerospace',
#  'walker',
#  'biterelated',
#  'cue',
#  'bluedio',
#  'thomassmonson',
#  'wbcshirl2',
#  'beth',
#  'tonight',
#  'pilloried',
#  'metastatic',
#  'sterlingknight',
#  'ethical',
#  'tedcruz2016',
#  'withstand',
#  'excessive',
#  'blitzes',
#  'butt',
#  'bbcnews',
#  '\x89û÷british',
#  'avengers',
#  'foodstand',
#  'dye',
#  'aesop',
#  'humidity',
#  'fx',
#  'humboldt',
#  'reason',
#  '11st',
#  'content',
#  'throwback',
#  'mean',
#  'promoted',
#  'firearm',
#  'scandals',
#  'christinalavv',
#  'sundays',
#  'bedroom',
#  'obsolete',
#  'transgender',
#  'recently',
#  'to\x89û',
#  'bundled',
#  'peale',
#  'driveby',
#  'postering',
#  'bloggers',
#  'motivator',
#  'puppyshogun',
#  'mental',
#  'hug',
#  'diarrhea',
#  'homie',
#  'pci',
#  'growingupincolorado\x89û\x9d',
#  'warn',
#  'yesterdays',
#  'lowkey',
#  'toes',
#  'iclowns',
#  'nemesiskpes',
#  'ganseyman',
#  'modest',
#  'hieroglyphics',
#  'reined',
#  'pivot',
#  'sunburned',
#  'flunkie',
#  'fiendnikki',
#  'abomb',
#  'closures',
#  'lauded',
#  'firetruck',
#  'craykain',
#  'sirius',
#  'daisycuttertz',
#  'iwate',
#  'siding',
#  'read\x89û',
#  'swept',
#  'penalties',
#  'toughens',
#  'batfanuk',
#  'thh',
#  'yycfringe',
#  'routecomplex',
#  'spurs',
#  'exposure',
#  'understood',
#  'esevu',
#  'collar',
#  'wowo',
#  'approaching',
#  'comment',
#  'morningjoe',
#  'reconnect',
#  'choppergatebronwynbishopauspol',
#  'barbitwins',
#  'latest',
#  'hardstyle',
#  'conversations',
#  'lwilliams13',
#  'naypyidaw',
#  'suho',
#  'tumblr',
#  'ultimate',
#  'testa',
#  'burton',
#  'londonfire',
#  'brings',
#  'weeklong',
#  'vj44',
#  'sponsor',
#  'marlene',
#  'acura',
#  'lifestyle',
#  'cable',
#  'coursing',
#  'eu',
#  'byr',
#  'nonenglish',
#  'murlo',
#  'dewdney',
#  'owner',
#  'brace',
#  'cross',
#  'sorrower',
#  'roundhouse',
#  'write',
#  'trombonetristan',
#  'cali',
#  'neck',
#  'sippin',
#  'frp',
#  'chesttorso',
#  'watersland',
#  'russell',
#  'rar',
#  'kyle',
#  's\x89û',
#  'pillow',
#  'beckyfeigin',
#  'africa',
#  'canoe',
#  'ojoubot',
#  'landsli',
#  'divers',
#  'tragic',
#  'relatives',
#  'mobile',
#  'thewebbeffect19',
#  'fucktard',
#  'thousands',
#  'ocalan',
#  'trinna',
#  'greater',
#  'jtruff23',
#  'trusted',
#  'juan',
#  'popular',
#  'utility',
#  'punishing',
#  'setting4success',
#  'opus',
#  'jaycootchi',
#  'newrelease',
#  'razedåê\x89ûò',
#  'studies',
#  'fangirling',
#  'uploading',
#  'patterns',
#  'browsers',
#  'u2',
#  'lynchburg',
#  'averted',
#  'bstop',
#  'died',
#  'vegetarian',
#  'sons',
#  'cessna',
#  'slingnews',
#  'then\x89û',
#  'lucysforsale',
#  'uranium',
#  'terrorism\x89ûª',
#  'tiaramarei',
#  'way',
#  'certificate',
#  'tastes',
#  '\x89û÷nuclear',
#  'fu',
#  'halt',
#  'busted',
#  'installation',
#  'reaching',
#  'asian',
#  'foamed',
#  'odell',
#  'teacher',
#  'standup',
#  'troupe',
#  '60ms',
#  'fel',
#  'digitalhealth',
#  'northgate',
#  'wftv',
#  'spears',
#  'nikostar',
#  'semasirtalks',
#  'fotofill',
#  'hearitfrompatty',
#  'pants',
#  'lgbt',
#  'ttes',
#  'stylish',
#  'windowgatribble',
#  'manchesterlite',
#  'grit',
#  'imbalancesare',
#  'currently',
#  'hmmm',
#  'mrc',
#  'sandy',
#  'flying',
#  'brought',
#  'scabs',
#  'japanese',
#  'lgl',
#  'recommendations',
#  'nashvilletraffic',
#  'paddytomlinson1',
#  'truestory',
#  'objective',
#  'shedding',
#  'glaucoma',
#  '\x89ûª93',
#  'holiday',
#  'jackets',
#  'hd',
#  'zippoline',
#  'customs',
#  'faith',
#  'sbnation',
#  'tattooed',
#  'animalrescue',
#  'sun',
#  'arsonistmusic',
#  'saturation',
#  'kill\x89û',
#  'mink',
#  'panda',
#  'proxy',
#  'scvsupremecourt',
#  'volcanodiscover',
#  'apperception',
#  'deccgovuk',
#  'ankles',
#  'picking',
#  'idwx',
#  'unlicensed',
#  'radler',
#  'mypillowstudio',
#  'official',
#  'proliferation',
#  'smaller',
#  'rtsampdemocracy',
#  'uncontrollable',
#  'song',
#  'automation',
#  'services',
#  '945hpa',
#  'promises',
#  'loan',
#  'concept',
#  'aminakh',
#  'library',
#  'minecraft',
#  'cupcake',
#  'perpetrators',
#  'chelsdelong12',
#  'creek',
#  'feels',
#  'killing',
#  'parksboardfacts',
#  'truediagnosis',
#  'brass',
#  'intragenerational',
#  '2500fps',
#  'surely',
#  'oversee',
#  'sort',
#  '79yearold',
#  'free',
#  'clarksville',
#  'mia',
#  'ameenshaikh3',
#  'cbcca',
#  'twcnewsclt',
#  'gesserit',
#  'strutted',
#  'hole',
#  'local\x89û',
#  'prior',
#  'ashes2ashes',
#  'paeds',
#  'married',
#  'imrazed',
#  'bump',
#  'robpulsenews',
#  'crazyindapeg',
#  'tops',
#  'grille',
#  'tommorow',
#  'harbor',
#  'santa',
#  'spoil',
#  'utd',
#  'count',
#  'noahshack',
#  'ocnj',
#  'control',
#  'abc7eyewitness',
#  'emily4everever',
#  'bomb',
#  'corn',
#  'meteors',
#  'dtn',
#  'locksmith',
#  'cspan',
#  'awareness',
#  'history',
#  'cyhi',
#  'letsfootball',
#  'mizuta',
#  'hoes',
#  'expect',
#  'weeks',
#  'murder',
#  '15th',
#  'hm',
#  'benothing',
#  'chips',
#  'zehrs',
#  'elem',
#  'ps',
#  'shanghai\x89ûªs',
#  'vibrates',
#  'iran\x89ûª',
#  'yennora',
#  'kelworldpeace',
#  'loves',
#  'fate',
#  'premises',
#  'basics',
#  'trailed',
#  'triumphant',
#  'achieving',
#  'also',
#  'listia',
#  'zaatari',
#  'ifunny',
#  'dig',
#  'mountain',
#  'fantasticfourfant4sticwhatever',
#  'delete',
#  'saturated',
#  'touched',
#  'nigerians',
#  'faroe',
#  'crematoria\x89ûª',
#  'univsfoundation',
#  'claimed',
#  'writes4coffee',
#  'layout',
#  'cyprus',
#  'destroyed',
#  'authentic',
#  'family',
#  'usdot',
#  'coffees',
#  'concern',
#  'doors',
#  'dancefloor',
#  'overloaded',
#  'buroker',
#  'films',
#  'eric',
#  'protestors',
#  'adventures',
#  'towards',
#  'timestack',
#  'racco',
#  'lovemywife1983',
#  'autumn',
#  'mattcohen4fake',
#  'starting',
#  'gilmanrocks7',
#  'chillin',
#  'queens',
#  'motogp',
#  'myths',
#  'jackholes',
#  'bleeding',
#  'hwymagellan',
#  'healthy',
#  'allies',
#  'helmet',
#  'genocide',
#  'valentines',
#  'dfr',
#  'wine',
#  'earthquake',
#  'mad',
#  '21k',
#  'robbed',
#  'pros',
#  'brenas',
#  'stops',
#  'usnwsgov',
#  'glorious',
#  'tracey',
#  'alaska',
#  'crack',
#  'card',
#  'croydonization',
#  'rossum',
#  'ants',
#  'balding',
#  'grouponuk',
#  'northumbria',
#  'i77',
#  'series',
#  'temper',
#  'shias',
#  'gotthard',
#  'emilymcfcheslop',
#  'sleeping',
#  'glory',
#  'feed',
#  'wheres',
#  'ipo',
#  'hao',
#  'nyt',
#  'panoramic',
#  'large',
#  'tonguetwister',
#  'comprehensive',
#  'crowned',
#  'scynic1',
#  'dual',
#  'affair',
#  'threat\x89ûª',
#  'foxysiren',
#  'rawfoodbliss',
#  '72w',
#  'nuff',
#  'violators',
#  'intern',
#  'literature',
#  'color',
#  'catechize',
#  'dm',
#  'fizzy',
#  'shopcollision',
#  'dnbheaven',
#  'multiracial',
#  'bask',
#  'berlin',
#  'snake',
#  'globiinclusion',
#  'rwy',
#  'therapy',
#  'census',
#  'usfs',
#  'platform',
#  'lightningooc',
#  'stolen',
#  'watching',
#  'abysmaljoiner',
#  'prosper',
#  'mina',
#  'big',
#  'ariaahrary',
#  'mountaineering',
#  'skill',
#  'give',
#  'linkury',
#  'trusty',
#  'code',
#  'cluei',
#  'davidduchovny',
#  'laurensicle',
#  'mcv',
#  'minuscule',
#  'latestnews',
#  'sincerelyevelnn',
#  'mraffleck',
#  'ukraine',
#  'mute',
#  'casino',
#  'weakening',
#  'boyfriend',
#  'indiansfor',
#  'split',
#  'estates',
#  'heather',
#  '\x89ûïafter',
#  'dtop77',
#  'trillion',
#  'todaythat',
#  'jenniferarri',
#  'aim',
#  'couple',
#  'northerncalifornia',
#  'caaaaaall',
#  'id',
#  'circa',
#  'meelllttting',
#  'soloquiero',
#  'talibans',
#  'baseball',
#  'occupational',
#  'nrc',
#  'hoke',
#  'yup',
#  'reviewers',
#  'josephus',
#  'lovelylikelaura',
#  'randomtourist',
#  'cstsmith',
#  'straighten',
#  'outfit',
#  'starr',
#  'defeat',
#  'patch',
#  'gunsense',
#  'r',
#  'natures',
#  'wesleylowery',
#  'neighborhood',
#  'dirknomissski',
#  'value',
#  'roar',
#  'finna',
#  'specs',
#  'bene',
#  'restore',
#  'soultech',
#  'ahrar',
#  'groceries',
#  'relax',
#  'engaged',
#  'critical',
#  'pays',
#  'post',
#  'kylekrenek',
#  'circuit',
#  'aquarius',
#  'carlilescanoelivery',
#  'steellord',
#  'lockdown',
#  'reduced',
#  'sfgiants',
#  'responsibility',
#  'hangout',
#  'police',
#  'whatevs',
#  'intersections',
#  'sportsroadhouse',
#  'themalemadonna',
#  'mapleridge',
#  'edwards',
#  'playstation',
#  'c\x89û',
#  'newest',
#  'calamities',
#  'berahino',
#  '60mph',
#  'palin',
#  'rapidcity',
#  'epic',
#  'bunch',
#  'banerjee',
#  'seanhannity',
#  'disorder',
#  'cocker',
#  'stresses',
#  'harman',
#  'kids',
#  'bordento',
#  'justin',
#  'foolish',
#  'thelonevirologi',
#  'ladins',
#  'suit',
#  'entertainment',
#  'hrsto',
#  'worked',
#  'forfeiting',
#  'netlabel',
#  'typography',
#  'airasia',
#  'sexuality',
#  'ffvii',
#  'apollo',
#  'trp',
#  'zoom',
#  'wfaaweather',
#  'mahalo',
#  'swami',
#  'whensoever',
#  'fried',
#  'lumixusa',
#  'helps',
#  'proportions',
#  'nigerian',
#  'choppas',
#  'appease',
#  'unpacked',
#  'memes',
#  'icymagistrate',
#  'cuddlesforjen',
#  'sharethis',
#  'fitzgerald',
#  'catalogue',
#  'cycling',
#  'astros',
#  'enemy',
#  'razak',
#  'foul',
#  'slammed',
#  'mirmanda11',
#  '3la',
#  'jebbush',
#  'stressful',
#  'gunfight',
#  'sunsets',
#  'mzmandilynn',
#  'totoooooooooo',
#  'kingnaruto',
#  'favorita',
#  'far',
#  'harmony',
#  'legs',
#  'seen',
#  'voltaic',
#  'ovofest',
#  'johnejefferson',
#  'tuning',
#  'joked',
#  'patriciatraina',
#  'makewaterwork',
#  'goz',
#  'coop',
#  'heavenly',
#  'atchisonsean',
#  'glenn',
#  'marinading',
#  'master',
#  'fell',
#  'relationship',
#  'refugees\x89û',
#  'redhanded',
#  'wn',
#  'gaza',
#  'downpours',
#  'carfest',
#  'ofr',
#  'moores',
#  'waves',
#  'cafetiere',
#  'advertise',
#  'plastics',
#  'cpr',
#  'morbid',
#  'baruch',
#  'watches',
#  'surfphoto',
#  'infinite',
#  'nbanews',
#  'motorcyclist',
#  'finn',
#  'gin',
#  'foster',
#  'follow',
#  'lcb',
#  'peoplecommunication',
#  'overzero',
#  'invalid',
#  'cpanel',
#  'bombed',
#  'ski',
#  'roofing',
#  'troubling',
#  'broadway',
#  'tammyw1997',
#  'bans',
#  'switching',
#  'defs',
#  'identification',
#  'spectrum',
#  'huyovoetripolye',
#  'ajw',
#  'grown',
#  'militarism',
#  'chapter',
#  'standwithpp',
#  'greggmair',
#  'penneys',
#  'joined',
#  'udhampuragain',
#  'stopping',
#  'drafted',
#  'florin',
#  'exceptionally',
#  'nlwx',
#  '\x89û÷nother\x89û\x9d',
#  'confirmed',
#  'ill',
#  'jacksonville',
#  'recoil',
#  'persecution',
#  'ianokavo96',
#  'ultimalucha',
#  'brian',
#  'simulating',
#  'studded',
#  'mineenjoybabes',
#  'enablement',
#  '46lv8',
#  'mhmmm',
#  'waterproof',
#  'managers',
#  'reddish',
#  'jet',
#  'specially',
#  'er',
#  'david5fernandez',
#  'cuffs',
#  'children',
#  'ii',
#  '4pm',
#  'empathy',
#  'skype',
#  'eating',
#  'garden',
#  'freshly',
#  'fewmoretweets',
#  'kallemattsons',
#  'football',
#  'vern',
#  'implicit',
#  'thisdayinhistory',
#  'hcg',
#  'mmfa',
#  'sht',
#  'organizationsfluctuations',
#  'connects',
#  'repped',
#  'rig',
#  'metre',
#  'draw',
#  'onlin',
#  'actively',
#  'crbzfz',
#  'withåêannihilation',
#  'benedict',
#  'tlvfacesauspol',
#  'hoodedu',
#  'spaceangelseven',
#  'alone',
#  'opera',
#  'twitsandiego',
#  'pizza',
#  'tps',
#  'gemma',
#  'let',
#  'canpoli',
#  'jewishpress',
#  'hrs',
#  'bullshit',
#  'quote',
#  'homeimprovement',
#  'sto',
#  'heroin',
#  'paints',
#  'domination',
#  'thursday',
#  'jamaica',
#  'pl',
#  'love',
#  'canagal',
#  'felons',
#  'skaggs',
#  'perform',
#  'kendall',
#  'waved',
#  'noi',
#  'derail',
#  'spinnellii',
#  'affecting',
#  'talisman',
#  'hannomottola',
#  'jdabe80',
#  'skanndtyagi',
#  'humanitarian',
#  'cackling',
#  'usagi',
#  'reebok',
#  'mayor',
#  'twisterlovesshania',
#  'dlh',
#  'entrepreneur',
#  'kfc',
#  'hijinks1967',
#  'orshow',
#  'spree',
#  'pileup',
#  'warmth',
#  'ante',
#  'nasahurricane',
#  'mmchale13',
#  'nypd',
#  'kristindavis',
#  'glen',
#  'win',
#  'robbiewilliams',
#  'dialyses',
#  'incidents',
#  'trust',
#  'html5',
#  'gallipoli',
#  'markkriegsman',
#  'majesty',
#  'dratomic420',
#  'nose',
#  'sethalphaeus',
#  'destroyer',
#  'happening',
#  'someones',
#  'fkhanage',
#  'asf',
#  'cooler',
#  'istg',
#  'shimmyfab',
#  'react',
#  'samanthaturne19',
#  '1040pm',
#  'quite',
#  'bhavanas',
#  'subconscious',
#  'epileptic\x89û',
#  'amirkingkhan',
#  'nout',
#  'symptoms',
#  'sinjar',
#  'statesville',
#  'emilio',
#  'pwhvgwax',
#  'akarb74',
#  'bigstar',
#  'michaelgbaron',
#  'caravans',
#  'dad',
#  'companionship',
#  'tutorial',
#  'doppler',
#  'mistaken',
#  'await',
#  'wyrmwood',
#  'renew911health',
#  'weak',
#  'stacks',
#  'gidiexclusixe',
#  'stern',
#  'jolie',
#  'bailout',
#  'magner',
#  'sharply',
#  'hamptonroadsforme',
#  'snowstormdespite',
#  'cats',
#  'hand',
#  'freemarketeer',
#  'wood',
#  'ps1',
#  'shoalstraffic',
#  'lakes',
#  'alllivesmatter',
#  'slander',
#  'describe',
#  'inspection',
#  'keampurley',
#  'buff',
#  'revolutionblight',
#  'norge2040',
#  'manzanita',
#  'blacklivesmatter',
#  'state',
#  'dvd',
#  'nazis',
#  'havent',
#  'non',
#  'opal',
#  'hazelannmac',
#  'malik',
#  'acaciapenn',
#  'eerie',
#  'utc',
#  'encounter',
#  'trying',
#  'miniature',
#  'skip',
#  'cabbage',
#  'goodnight',
#  'win10',
#  'refuse',
#  'replaced',
#  'xhnews',
#  'manually',
#  'knives',
#  'ships',
#  'afraid',
#  'jennasjems',
#  'mentalhealthgov',
#  'chairs',
#  'harm',
#  'sirensong21',
#  'appoints',
#  'tyler',
#  'antiblight',
#  'achieve',
#  '73km',
#  'uncomfortable',
#  'accionempresa',
#  'shotgun',
#  'beckarnley',
#  'ce',
#  'megaquake',
#  'summary',
#  'noticed',
#  'woken',
#  'procedures',
#  'saturday',
#  'ten4',
#  'monopolized',
#  'obamadhs',
#  'canvas',
#  'peel',
#  'feat',
#  'laighign',
#  'alarm',
#  'tryouts',
#  'skills',
#  'askcharley',
#  'diagnosis',
#  'clogs',
#  'swansea',
#  'seagull07',
#  'perkpearl',
#  'claiming',
#  'disowned',
#  'remodeled',
#  'still',
#  'carlachamorros',
#  'betz',
#  'disciplinary',
#  'disgrace',
#  'contactenergy',
#  'peterduttonmp',
#  'panik',
#  'yahooschwab',
#  'eeasterling2',
#  'newhart2010',
#  'stood',
#  'freestyles',
#  ...}

# %%
def creo_list_palabras(target):
    lista_palabras=[]
    
    for x in df[df['target']==target]['words']:
        for i in x:
            lista_palabras.append(i)
    return lista_palabras

# Dada una lista de palabras, devuelve un diccionario de
# pares de palabra-frecuencia.

def listaPalabrasDicFrec(listaPalabras):
    frecuenciaPalab = [listaPalabras.count(p) for p in listaPalabras]
    return dict(list(zip(listaPalabras,frecuenciaPalab)))

# Ordena un diccionario de pares palabra-frecuencia en
# orden de frecuencia descendente.

def ordenaDicFrec(dicfrec):
    aux = [(dicfrec[key], key) for key in dicfrec]
    aux.sort()
    aux.reverse()
    return aux

lista_palabras_reales = creo_list_palabras(0)
dic_frec_reales = ordenaDicFrec(listaPalabrasDicFrec(lista_palabras_reales))
dic_frec_reales

#lista_palabras_reales = creo_list_palabras(1)
# Out:
# [(253, 'like'),
#  (168, 'new'),
#  (112, 'body'),
#  (99, 'via'),
#  (91, 'people'),
#  (90, 'video'),
#  (89, 'love'),
#  (85, 'know'),
#  (84, 'back'),
#  (83, 'us'),
#  (83, 'time'),
#  (83, 'got'),
#  (82, 'see'),
#  (81, 'full'),
#  (81, 'emergency'),
#  (81, 'cant'),
#  (78, 'day'),
#  (76, 'youtube'),
#  (75, 'going'),
#  (72, 'still'),
#  (72, 'fire'),
#  (67, 'want'),
#  (67, 'good'),
#  (65, 'think'),
#  (64, '3'),
#  (62, 'world'),
#  (61, 'man'),
#  (61, 'lol'),
#  (60, 'rt'),
#  (60, 'life'),
#  (59, 'u'),
#  (58, 'youre'),
#  (58, 'first'),
#  (56, 'news'),
#  (56, 'last'),
#  (55, 'way'),
#  (55, 'really'),
#  (55, 'need'),
#  (55, 'burning'),
#  (54, 'work'),
#  (54, 'make'),
#  (53, 'best'),
#  (52, 'let'),
#  (51, 'much'),
#  (51, 'many'),
#  (51, 'even'),
#  (50, 'take'),
#  (48, 'say'),
#  (48, 'help'),
#  (47, 'wreck'),
#  (47, 'great'),
#  (46, 'right'),
#  (46, 'feel'),
#  (46, 'content'),
#  (45, 'hot'),
#  (44, 'please'),
#  (44, 'never'),
#  (44, 'look'),
#  (44, 'god'),
#  (44, 'fear'),
#  (44, 'every'),
#  (43, 'could'),
#  (43, '5'),
#  (42, 'read'),
#  (42, 'cross'),
#  (42, 'bags'),
#  (42, 'ass'),
#  (41, 'today'),
#  (41, 'ever'),
#  (40, 'top'),
#  (40, 'night'),
#  (40, 'fucking'),
#  (39, 'reddit'),
#  (39, 'come'),
#  (39, 'bag'),
#  (38, 'year'),
#  (38, 'without'),
#  (38, 'may'),
#  (38, 'hes'),
#  (38, 'getting'),
#  (38, 'everyone'),
#  (38, 'check'),
#  (37, 'shit'),
#  (37, 'screaming'),
#  (37, 'ruin'),
#  (37, 'panic'),
#  (37, 'liked'),
#  (37, 'bloody'),
#  (37, 'another'),
#  (36, 'wrecked'),
#  (36, 'well'),
#  (36, 'smoke'),
#  (36, 'school'),
#  (36, 'ive'),
#  (36, 'explode'),
#  (36, 'death'),
#  (36, 'always'),
#  (35, 'watch'),
#  (35, 'thats'),
#  (35, 'harm'),
#  (35, 'face'),
#  (35, 'disaster'),
#  (35, 'crash'),
#  (35, 'coming'),
#  (35, 'bad'),
#  (34, 'sinking'),
#  (34, 'military'),
#  (34, 'home'),
#  (34, 'buildings'),
#  (34, 'black'),
#  (34, '1'),
#  (33, 'war'),
#  (33, 'stop'),
#  (33, 'next'),
#  (33, 'made'),
#  (33, 'head'),
#  (33, 'dead'),
#  (33, 'car'),
#  (33, 'better'),
#  (33, 'armageddon'),
#  (33, 'also'),
#  (33, '4'),
#  (32, 'w'),
#  (32, 'twister'),
#  (32, 'traumatised'),
#  (32, 'storm'),
#  (32, 'show'),
#  (32, 'screamed'),
#  (32, 'police'),
#  (32, 'loud'),
#  (32, 'hope'),
#  (32, 'gonna'),
#  (32, 'fuck'),
#  (32, 'free'),
#  (32, 'fall'),
#  (32, 'ebay'),
#  (32, 'curfew'),
#  (32, 'crush'),
#  (32, 'blew'),
#  (31, 'said'),
#  (31, 'panicking'),
#  (31, 'nuclear'),
#  (31, 'little'),
#  (31, 'deluge'),
#  (31, 'blood'),
#  (30, 'wanna'),
#  (30, 'someone'),
#  (30, 'put'),
#  (30, 'live'),
#  (30, 'girl'),
#  (30, 'destroy'),
#  (30, 'change'),
#  (30, 'bleeding'),
#  (30, 'attack'),
#  (29, 'survive'),
#  (29, 'song'),
#  (29, 'run'),
#  (29, 'quarantine'),
#  (29, 'lava'),
#  (29, 'keep'),
#  (29, 'ill'),
#  (29, 'game'),
#  (29, 'collide'),
#  (29, 'burned'),
#  (29, 'bomb'),
#  (29, 'army'),
#  (28, '\x89û'),
#  (28, 'trouble'),
#  (28, 'things'),
#  (28, 'theres'),
#  (28, 'sunk'),
#  (28, 'stock'),
#  (28, 'soon'),
#  (28, 'shoulder'),
#  (28, 'services'),
#  (28, 'phone'),
#  (28, 'movie'),
#  (28, 'long'),
#  (28, 'lets'),
#  (28, 'inundated'),
#  (28, 'flattened'),
#  (28, 'flames'),
#  (28, 'drown'),
#  (28, 'destroyed'),
#  (28, 'desolation'),
#  (28, 'catastrophe'),
#  (28, 'blown'),
#  (28, 'blazing'),
#  (28, 'battle'),
#  (27, 'trapped'),
#  (27, 'summer'),
#  (27, 'obliterated'),
#  (27, 'lot'),
#  (27, 'looks'),
#  (27, 'injury'),
#  (27, 'injuries'),
#  (27, 'electrocute'),
#  (27, 'destruction'),
#  (27, 'demolish'),
#  (27, 'danger'),
#  (27, 'crushed'),
#  (27, 'bang'),
#  (27, 'bagging'),
#  (26, 'years'),
#  (26, 'week'),
#  (26, 'two'),
#  (26, 'twitter'),
#  (26, 'thank'),
#  (26, 'screams'),
#  (26, 'save'),
#  (26, 'riot'),
#  (26, 'real'),
#  (26, 'plan'),
#  (26, 'oh'),
#  (26, 'obliteration'),
#  (26, 'obliterate'),
#  (26, 'music'),
#  (26, 'meltdown'),
#  (26, 'cause'),
#  (26, 'big'),
#  (26, 'away'),
#  (26, 'apocalypse'),
#  (25, 'woman'),
#  (25, 'whole'),
#  (25, 'thunder'),
#  (25, 'thing'),
#  (25, 'survived'),
#  (25, 'sure'),
#  (25, 'set'),
#  (25, 're\x89û'),
#  (25, 'mudslide'),
#  (25, 'high'),
#  (25, 'hazard'),
#  (25, 'fun'),
#  (25, 'fan'),
#  (25, 'end'),
#  (25, 'drowning'),
#  (25, 'detonate'),
#  (25, 'cliff'),
#  (24, 'white'),
#  (24, 'weapons'),
#  (24, 'weapon'),
#  (24, 'upheaval'),
#  (24, 'play'),
#  (24, 'pandemonium'),
#  (24, 'nowplaying'),
#  (24, 'light'),
#  (24, 'heart'),
#  (24, 'heard'),
#  (24, 'goes'),
#  (24, 'exploded'),
#  (24, 'collapse'),
#  (23, 'zone'),
#  (23, 'yet'),
#  (23, 'wounds'),
#  (23, 'words'),
#  (23, 'whirlwind'),
#  (23, 'thought'),
#  (23, 'sound'),
#  (23, 'since'),
#  (23, 'quarantined'),
#  (23, 'policy'),
#  (23, 'market'),
#  (23, 'id'),
#  (23, 'hit'),
#  (23, 'hellfire'),
#  (23, 'damage'),
#  (23, 'collapsed'),
#  (23, 'blight'),
#  (23, 'beautiful'),
#  (23, 'baby'),
#  (23, 'around'),
#  (23, 'annihilated'),
#  (22, 'windstorm'),
#  (22, 'whats'),
#  (22, 'ur'),
#  (22, 'tonight'),
#  (22, 'tomorrow'),
#  (22, 'thanks'),
#  (22, 'stretcher'),
#  (22, 'start'),
#  (22, 'something'),
#  (22, 'sirens'),
#  (22, 'red'),
#  (22, 'photo'),
#  (22, 'nothing'),
#  (22, 'mass'),
#  (22, 'making'),
#  (22, 'left'),
#  (22, 'kids'),
#  (22, 'guys'),
#  (22, 'gets'),
#  (22, 'detonation'),
#  (22, 'already'),
#  (21, 'yes'),
#  (21, 'wait'),
#  (21, 'trying'),
#  (21, 'send'),
#  (21, 'old'),
#  (21, 'makes'),
#  (21, 'leather'),
#  (21, 'job'),
#  (21, 'house'),
#  (21, 'hey'),
#  (21, 'happy'),
#  (21, 'finally'),
#  (21, 'fatality'),
#  (21, 'didnt'),
#  (21, 'demolition'),
#  (21, 'demolished'),
#  (21, 'cool'),
#  (21, 'care'),
#  (21, 'came'),
#  (21, 'book'),
#  (21, 'avalanche'),
#  (21, 'accident'),
#  (21, '9'),
#  (20, 'wont'),
#  (20, 'went'),
#  (20, 'used'),
#  (20, 'trauma'),
#  (20, 'times'),
#  (20, 'stay'),
#  (20, 'shes'),
#  (20, 'probably'),
#  (20, 'pick'),
#  (20, 'part'),
#  (20, 'lightning'),
#  (20, 'horrible'),
#  (20, 'hell'),
#  (20, 'food'),
#  (20, 'family'),
#  (20, 'electrocuted'),
#  (20, 'bar'),
#  (20, 'ball'),
#  (19, 'wrong'),
#  (19, 'women'),
#  (19, 'truck'),
#  (19, 'space'),
#  (19, 'self'),
#  (19, 'rescue'),
#  (19, 'offensive'),
#  (19, 'mayhem'),
#  (19, 'maybe'),
#  (19, 'low'),
#  (19, 'jobs'),
#  (19, 'flood'),
#  (19, 'find'),
#  (19, 'feeling'),
#  (19, 'everything'),
#  (19, 'deluged'),
#  (19, 'data'),
#  (19, 'call'),
#  (19, 'brown'),
#  (19, 'bombed'),
#  (19, 'bc'),
#  (19, 'anything'),
#  (18, '\x89ûò'),
#  (18, 'womens'),
#  (18, 'story'),
#  (18, 'spot'),
#  (18, 'siren'),
#  (18, 'responders'),
#  (18, 'rescued'),
#  (18, 'remember'),
#  (18, 'pretty'),
#  (18, 'person'),
#  (18, 'online'),
#  (18, 'okay'),
#  (18, 'ok'),
#  (18, 'natural'),
#  (18, 'hours'),
#  (18, 'eyes'),
#  (18, 'derail'),
#  (18, 'city'),
#  (18, 'chemical'),
#  (18, 'cake'),
#  (18, 'banned'),
#  (18, 'actually'),
#  (17, 'yeah'),
#  (17, 'waves'),
#  (17, 'use'),
#  (17, 'tv'),
#  (17, 'tsunami'),
#  (17, 'team'),
#  (17, 'stand'),
#  (17, 'sorry'),
#  (17, 'side'),
#  (17, 'seen'),
#  (17, 'prebreak'),
#  (17, 'money'),
#  (17, 'mom'),
#  (17, 'might'),
#  (17, 'meek'),
#  (17, 'lord'),
#  (17, 'longer'),
#  (17, 'landslide'),
#  (17, 'ladies'),
#  (17, 'hollywood'),
#  (17, 'hijacking'),
#  (17, 'half'),
#  (17, 'eyewitness'),
#  (17, 'engulfed'),
#  (17, 'effect'),
#  (17, 'drowned'),
#  (17, 'done'),
#  (17, 'doesnt'),
#  (17, 'desolate'),
#  (17, 'collided'),
#  (17, 'business'),
#  (17, 'believe'),
#  (17, 'anyone'),
#  (17, 'ambulance'),
#  (17, '7'),
#  (16, '\x89ûó'),
#  (16, 'though'),
#  (16, 'rubble'),
#  (16, 'river'),
#  (16, 'reddits'),
#  (16, 'quiz'),
#  (16, 'national'),
#  (16, 'name'),
#  (16, 'miners'),
#  (16, 'looking'),
#  (16, 'lmao'),
#  (16, 'literally'),
#  (16, 'listen'),
#  (16, 'hiring'),
#  (16, 'hail'),
#  (16, 'haha'),
#  (16, 'gbbo'),
#  (16, 'friends'),
#  (16, 'fires'),
#  (16, 'favorite'),
#  (16, 'emmerdale'),
#  (16, 'drake'),
#  (16, 'die'),
#  (16, 'class'),
#  (16, 'breaking'),
#  (16, 'blizzard'),
#  (16, 'blaze'),
#  (16, 'blast'),
#  (16, 'appears'),
#  (16, 'ancient'),
#  (16, 'ablaze'),
#  (16, '2015'),
#  (15, 'wind'),
#  (15, 'win'),
#  (15, 'water'),
#  (15, 'watching'),
#  (15, 'vs'),
#  (15, 'try'),
#  (15, 'trust'),
#  (15, 'theyre'),
#  (15, 'tell'),
#  (15, 'subreddits'),
#  (15, 'star'),
#  (15, 'snowstorm'),
#  (15, 'says'),
#  (15, 'saw'),
#  (15, 'radio'),
#  (15, 'r'),
#  (15, 'post'),
#  (15, 'pay'),
#  (15, 'needs'),
#  (15, 'must'),
#  (15, 'link'),
#  (15, 'level'),
#  (15, 'led'),
#  (15, 'leave'),
#  (15, 'knock'),
#  (15, 'islam'),
#  (15, 'ignition'),
#  (15, 'hostage'),
#  (15, 'hear'),
#  (15, 'hazardous'),
#  (15, 'hate'),
#  (15, 'guy'),
#  (15, 'forest'),
#  (15, 'floods'),
#  (15, 'fatalities'),
#  (15, 'fast'),
#  (15, 'fashion'),
#  (15, 'failure'),
#  (15, 'evacuate'),
#  (15, 'deal'),
#  (15, 'days'),
#  (15, 'damn'),
#  (15, 'course'),
#  (15, 'blue'),
#  (15, 'awesome'),
#  (15, 'attacked'),
#  (15, '6'),
#  (14, 'wild'),
#  (14, 'wants'),
#  (14, 'train'),
#  (14, 'tote'),
#  (14, 'talk'),
#  (14, 'state'),
#  (14, 'soul'),
#  (14, 'sinkhole'),
#  (14, 'ship'),
#  (14, 'seeing'),
#  (14, 'rise'),
#  (14, 'rain'),
#  (14, 'power'),
#  (14, 'playing'),
#  (14, 'plans'),
#  (14, 'photos'),
#  (14, 'past'),
#  (14, 'nearby'),
#  (14, 'move'),
#  (14, 'mode'),
#  (14, 'miss'),
#  (14, 'men'),
#  (14, 'likely'),
#  (14, 'king'),
#  (14, 'hijacker'),
#  (14, 'heat'),
#  (14, 'health'),
#  (14, 'handbag'),
#  (14, 'gop'),
#  (14, 'friend'),
#  (14, 'follow'),
#  (14, 'fedex'),
#  (14, 'eye'),
#  (14, 'explosion'),
#  (14, 'entire'),
#  (14, 'earth'),
#  (14, 'crashed'),
#  (14, 'computers'),
#  (14, 'chile'),
#  (14, 'chance'),
#  (14, 'alone'),
#  (14, 'almost'),
#  (14, 'aint'),
#  (14, 'added'),
#  (14, '11'),
#  (14, '10'),
#  (13, 'x'),
#  (13, 'wow'),
#  (13, 'wounded'),
#  (13, 'wonder'),
#  (13, 'wanted'),
#  (13, 'upon'),
#  (13, 'unconfirmed'),
#  (13, 'tweet'),
#  (13, 'tragedy'),
#  (13, 'thinking'),
#  (13, 'super'),
#  (13, 'sign'),
#  (13, 'service'),
#  (13, 'seismic'),
#  (13, 'second'),
#  (13, 'road'),
#  (13, 'released'),
#  (13, 'reason'),
#  (13, 'reactor'),
#  (13, 'playlist'),
#  (13, 'pain'),
#  (13, 'outside'),
#  (13, 'niggas'),
#  (13, 'neighbours'),
#  (13, 'learn'),
#  (13, 'lamp'),
#  (13, 'hurricane'),
#  (13, 'hard'),
#  (13, 'gt'),
#  (13, 'government'),
#  (13, 'flooding'),
#  (13, 'famine'),
#  (13, 'dust'),
#  (13, 'download'),
#  (13, 'dance'),
#  (13, 'comes'),
#  (13, 'child'),
#  (13, 'casualty'),
#  (13, 'career'),
#  (13, 'biggest'),
#  (13, 'bed'),
#  (13, 'become'),
#  (13, 'beach'),
#  (13, 'art'),
#  (13, 'arent'),
#  (13, 'annihilation'),
#  (13, 'angry'),
#  (13, 'album'),
#  (13, '20'),
#  (12, 'wedding'),
#  (12, 'weather'),
#  (12, 'wake'),
#  (12, 'view'),
#  (12, 'turn'),
#  (12, 'tried'),
#  (12, 'totally'),
#  (12, 'support'),
#  (12, 'structural'),
#  (12, 'sex'),
#  (12, 'series'),
#  (12, 'secret'),
#  (12, 'scared'),
#  (12, 'saying'),
#  (12, 'running'),
#  (12, 'rioting'),
#  (12, 'refugees'),
#  (12, 'place'),
#  (12, 'peace'),
#  (12, 'party'),
#  (12, 'order'),
#  (12, 'offroad'),
#  (12, 'nice'),
#  (12, 'n'),
#  (12, 'mop'),
#  (12, 'mad'),
#  (12, 'louis'),
#  (12, 'kill'),
#  (12, 'join'),
#  (12, 'inside'),
#  (12, 'hijack'),
#  (12, 'hair'),
#  (12, 'gtgt'),
#  (12, 'gave'),
#  (12, 'funtenna'),
#  (12, 'front'),
#  (12, 'film'),
#  (12, 'fight'),
#  (12, 'faux'),
#  (12, 'far'),
#  (12, 'else'),
#  (12, 'dog'),
#  (12, 'cree'),
#  (12, 'buy'),
#  (12, 'businesses'),
#  (12, 'broke'),
#  (12, 'bring'),
#  (12, 'bioterror'),
#  (12, 'aftershock'),
#  (12, '12'),
#  (11, 'wave'),
#  (11, 'united'),
#  (11, 'turned'),
#  (11, 'text'),
#  (11, 'st'),
#  (11, 'sounds'),
#  (11, 'sometimes'),
#  (11, 'smaug'),
#  (11, 'rules'),
#  (11, 'purse'),
#  (11, 'public'),
#  (11, 'open'),
#  (11, 'omg'),
#  (11, 'official'),
#  (11, 'nigga'),
#  (11, 'murderer'),
#  (11, 'media'),
#  (11, 'means'),
#  (11, 'lucky'),
#  (11, 'latest'),
#  (11, 'land'),
#  (11, 'lady'),
#  (11, 'insurance'),
#  (11, 'instead'),
#  (11, 'history'),
#  (11, 'havent'),
#  (11, 'guess'),
#  (11, 'gems'),
#  (11, 'games'),
#  (11, 'funny'),
#  (11, 'fatal'),
#  (11, 'enough'),
#  (11, 'edm'),
#  (11, 'driving'),
#  (11, 'don\x89ûªt'),
#  (11, 'direction'),
#  (11, 'devastated'),
#  (11, 'date'),
#  (11, 'daily'),
#  (11, 'dad'),
#  (11, 'crazy'),
#  (11, 'couple'),
#  (11, 'control'),
#  (11, 'complete'),
#  (11, 'centre'),
#  (11, 'cat'),
#  (11, 'cable'),
#  (11, 'building'),
#  (11, 'august'),
#  (11, 'arsonist'),
#  (11, 'arianagrande'),
#  (11, 'apollo'),
#  (11, 'absolutely'),
#  (11, '50'),
#  (11, '100'),
#  (10, 'youll'),
#  (10, 'worst'),
#  (10, 'worlds'),
#  (10, 'working'),
#  (10, 'wish'),
#  (10, 'weekend'),
#  (10, 'version'),
#  (10, 'truth'),
#  (10, 'together'),
#  (10, 'till'),
#  (10, 'tablet'),
#  (10, 'survivors'),
#  (10, 'straight'),
#  (10, 'started'),
#  (10, 'share'),
#  (10, 'shall'),
#  (10, 'security'),
#  (10, 'room'),
#  (10, 'rock'),
#  (10, 'reasons'),
#  (10, 'ready'),
#  (10, 'rather'),
#  (10, 'rainstorm'),
#  (10, 'press'),
#  (10, 'petition'),
#  (10, 'park'),
#  (10, 'others'),
#  (10, 'michael'),
#  (10, 'least'),
#  (10, 'jeb'),
#  (10, 'internet'),
#  (10, 'injured'),
#  (10, 'info'),
#  (10, 'hostages'),
#  (10, 'hasnt'),
#  (10, 'handbags'),
#  (10, 'guide'),
#  (10, 'group'),
#  (10, 'glass'),
#  (10, 'girls'),
#  (10, 'future'),
#  (10, 'feat'),
#  (10, 'evacuation'),
#  (10, 'emotional'),
#  (10, 'dude'),
#  (10, 'drive'),
#  (10, 'drink'),
#  (10, 'door'),
#  (10, 'displaced'),
#  (10, 'department'),
#  (10, 'deep'),
#  (10, 'deaths'),
#  (10, 'de'),
#  (10, 'country'),
#  (10, 'chinas'),
#  (10, 'children'),
#  (10, 'bush'),
#  (10, 'bus'),
#  (10, 'break'),
#  (10, 'boy'),
#  (10, 'bitch'),
#  (10, 'birthday'),
#  (10, 'beyond'),
#  (10, 'behind'),
#  (10, 'arson'),
#  (10, 'answer'),
#  (10, 'america'),
#  (10, 'ahead'),
#  (10, 'ago'),
#  (10, '8'),
#  (9, 'yall'),
#  (9, 'worse'),
#  (9, 'welcome'),
#  (9, 'wasnt'),
#  (9, 'walking'),
#  (9, 'violent'),
#  (9, 'usa'),
#  (9, 'update'),
#  (9, 'trump'),
#  (9, 'transport'),
#  (9, 'traffic'),
#  (9, 'town'),
#  (9, 'tornado'),
#  (9, 'tired'),
#  (9, 'thousands'),
#  (9, 'texas'),
#  (9, 'test'),
#  (9, 'terrorism'),
#  (9, 'teen'),
#  (9, 'technology'),
#  (9, 'taking'),
#  (9, 'taken'),
#  (9, 'sun'),
#  (9, 'stage'),
#  (9, 'sleeping'),
#  (9, 'sit'),
#  (9, 'shape'),
#  (9, 'sent'),
#  (9, 'sense'),
#  (9, 'selfimage'),
#  (9, 'secrets'),
#  (9, 'screen'),
#  (9, 'round'),
#  (9, 'ross'),
#  (9, 'reading'),
#  (9, 'property'),
#  (9, 'pray'),
#  (9, 'ppl'),
#  (9, 'played'),
#  (9, 'planned'),
#  (9, 'pile'),
#  (9, 'paul'),
#  (9, 'opening'),
#  (9, 'oil'),
#  (9, 'occurred'),
#  (9, 'murder'),
#  (9, 'morning'),
#  (9, 'months'),
#  (9, 'moment'),
#  (9, 'mod'),
#  (9, 'middle'),
#  (9, 'mean'),
#  (9, 'loved'),
#  (9, 'lost'),
#  (9, 'london'),
#  (9, 'limited'),
#  (9, 'lead'),
#  (9, 'lab'),
#  (9, 'kindle'),
#  (9, 'kinda'),
#  (9, 'isnt'),
#  (9, 'iran'),
#  (9, 'international'),
#  (9, 'interesting'),
#  (9, 'idea'),
#  (9, 'ice'),
#  (9, 'hobo'),
#  (9, 'hobbit'),
#  (9, 'hilarious'),
#  (9, 'happened'),
#  (9, 'hand'),
#  (9, 'green'),
#  (9, 'glad'),
#  (9, 'giving'),
#  (9, 'give'),
#  (9, 'general'),
#  (9, 'gay'),
#  (9, 'financial'),
#  (9, 'feet'),
#  (9, 'feels'),
#  (9, 'fantasy'),
#  (9, 'fans'),
#  (9, 'episode'),
#  (9, 'epicentre'),
#  (9, 'either'),
#  (9, 'double'),
#  (9, 'different'),
#  (9, 'devastation'),
#  (9, 'desires'),
#  (9, 'delivers'),
#  (9, 'cyclone'),
#  (9, 'cover'),
#  (9, 'comment'),
#  (9, 'combo'),
#  (9, 'colour'),
#  (9, 'cold'),
#  (9, 'character'),
#  (9, 'catastrophic'),
#  (9, 'brought'),
#  (9, 'boat'),
#  (9, 'block'),
#  (9, 'bioterrorism'),
#  (9, 'apply'),
#  (9, 'air'),
#  (9, 'aba'),
#  (9, '30'),
#  (9, '13'),
#  (8, 'word'),
#  (8, 'woke'),
#  (8, 'wired'),
#  (8, 'walk'),
#  (8, 'vote'),
#  (8, 'unless'),
#  (8, 'true'),
#  (8, 'travel'),
#  (8, 'totaling'),
#  (8, 'took'),
#  (8, 'told'),
#  (8, 'tickets'),
#  (8, 'thunderstorm'),
#  (8, 'tho'),
#  (8, 'terrorist'),
#  (8, 'tears'),
#  (8, 'takes'),
#  (8, 'stuff'),
#  (8, 'standard'),
#  (8, 'somebody'),
#  (8, 'social'),
#  (8, 'sky'),
#  (8, 'sitting'),
#  (8, 'single'),
#  (8, 'silver'),
#  (8, 'shouldnt'),
#  (8, 'ships'),
#  (8, 'sensorsenso'),
#  (8, 'sensor'),
#  (8, 'season'),
#  (8, 'sandstorm'),
#  (8, 'salt'),
#  (8, 'sale'),
#  (8, 'releases'),
#  (8, 'rate'),
#  (8, 'problem'),
#  (8, 'prevent'),
#  (8, 'possible'),
#  (8, 'poor'),
#  (8, 'perfect'),
#  (8, 'original'),
#  (8, 'ones'),
#  (8, 'obama'),
#  (8, 'o784'),
#  (8, 'number'),
#  (8, 'mortal'),
#  (8, 'metal'),
#  (8, 'match'),
#  (8, 'mary'),
#  (8, 'lose'),
#  (8, 'line'),
#  (8, 'lil'),
#  (8, 'large'),
#  (8, 'kombat'),
#  (8, 'killer'),
#  (8, 'justinbieber'),
#  (8, 'joe'),
#  (8, 'isis'),
#  (8, 'involving'),
#  (8, 'huge'),
#  (8, 'horse'),
#  (8, 'hold'),
#  (8, 'hero'),
#  (8, 'hands'),
#  (8, 'guns'),
#  (8, 'gotta'),
#  (8, 'gone'),
#  (8, 'gold'),
#  (8, 'found'),
#  (8, 'forever'),
#  (8, 'football'),
#  (8, 'fleets'),
#  (8, 'fat'),
#  (8, 'fact'),
#  (8, 'facebook'),
#  (8, 'easy'),
#  (8, 'dream'),
#  (8, 'dnb'),
#  (8, 'disney'),
#  (8, 'disco'),
#  (8, 'directioners'),
#  (8, 'derailed'),
#  (8, 'da'),
#  (8, 'crying'),
#  (8, 'court'),
#  (8, 'cook'),
#  (8, 'common'),
#  (8, 'climate'),
#  (8, 'changes'),
#  (8, 'ceo'),
#  (8, 'center'),
#  (8, 'camp'),
#  (8, 'build'),
#  (8, 'brain'),
#  (8, 'books'),
#  (8, 'beyhive'),
#  (8, 'beat'),
#  (8, 'australia'),
#  (8, 'asked'),
#  (8, 'ask'),
#  (8, 'anymore'),
#  (8, 'animal'),
#  (8, 'amazon'),
#  (8, 'access'),
#  (8, '2014'),
#  (8, '15'),
#  (7, 'young'),
#  (7, 'yo'),
#  (7, 'wtf'),
#  (7, 'writing'),
#  (7, 'worth'),
#  (7, 'worry'),
#  (7, 'wife'),
#  (7, 'watched'),
#  (7, 'vuitton'),
#  (7, 'volcano'),
#  (7, 'voice'),
#  (7, 'vehicle'),
#  (7, 'v'),
#  (7, 'universe'),
#  (7, 'uk'),
#  (7, 'tweets'),
#  (7, 'trapmusic'),
#  (7, 'total'),
#  (7, 'tongue'),
#  (7, 'threat'),
#  (7, 'syrian'),
#  (7, 'stream'),
#  (7, 'stories'),
#  (7, 'stone'),
#  ...]

# %%
#corrector de palabras
spell = SpellChecker()
def correct_spellings(text):
    corrected_text = []
    misspelled_words = spell.unknown(text.split())
    for word in text.split():
        if word in misspelled_words:
            corrected_text.append(spell.correction(word))
        else:
            corrected_text.append(word)
    return " ".join(corrected_text)

df['text']=df['text'].apply(lambda x : correct_spellings(x))
# Out:
# 'eunice joke iii she needs to chill and answer calmly its not like she s being attacked'
